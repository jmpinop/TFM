# %% [markdown]
# # Vamos a adquirir y preparar los datos de las tres fuentes que tenemos:
# ### 1.- Nº de manchas solares (Spots)
# ### 2.- LLamaradas solares (Flares)
# ### 3.- Eyecciones de masa coronal (CMEs)

# %%
# Importaciones necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style = 'whitegrid')
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %% [markdown]
# # Spots

# %%
# Echemos un vistazo al fichero
# !cat "Ficheros/Manchas/SN_d_tot_V2.0.csv" | head
# Out:
# 1818;01;01;1818.001;  -1; -1.0;   0;1
# 1818;01;02;1818.004;  -1; -1.0;   0;1
# 1818;01;03;1818.007;  -1; -1.0;   0;1
# 1818;01;04;1818.010;  -1; -1.0;   0;1
# 1818;01;05;1818.012;  -1; -1.0;   0;1
# 1818;01;06;1818.015;  -1; -1.0;   0;1
# 1818;01;07;1818.018;  -1; -1.0;   0;1
# 1818;01;08;1818.021;  65; 10.2;   1;1
# 1818;01;09;1818.023;  -1; -1.0;   0;1
# 1818;01;10;1818.026;  -1; -1.0;   0;1
# cat: write error: Broken pipe

# %%
# Con la descripción de los datos que tenemos (ver "SN_d_tot_V2.0_description.txt") y 
# sabiendo que los NaN se coresponden con el valor -1 (y que también tenemos 0) podemos ya cargarlo:
columns = ['Year', 'Month', 'Day', 'Fraction', 'Spots', 'Stdev', 'Observ', 'Def/Prov']
df = pd.read_csv('Ficheros/Manchas/SN_d_tot_V2.0.csv', sep = ';', header = None, names = columns, na_values = [0, -1])
df
# Out:
#        Year  Month  Day  Fraction  Spots  Stdev  Observ  Def/Prov
# 0      1818      1    1  1818.001     -1    NaN       0       1.0
# 1      1818      1    2  1818.004     -1    NaN       0       1.0
# 2      1818      1    3  1818.007     -1    NaN       0       1.0
# 3      1818      1    4  1818.010     -1    NaN       0       1.0
# 4      1818      1    5  1818.012     -1    NaN       0       1.0
# ...     ...    ...  ...       ...    ...    ...     ...       ...
# 73834  2020      2   25  2020.152      0    NaN      25       NaN
# 73835  2020      2   26  2020.154      0    NaN      30       NaN
# 73836  2020      2   27  2020.157      0    NaN      28       NaN
# 73837  2020      2   28  2020.160      0    NaN      32       NaN
# 73838  2020      2   29  2020.163      0    NaN      23       NaN
#
# [73839 rows x 8 columns]

# %%
# No parece que nos haya transformado en NaN los datos de 'Spots', debe haber espacios en esa columna,
# vamos a quitarlos
columns = ['Year', 'Month', 'Day', 'Fraction', 'Spots', 'Stdev', 'Observ', 'Def/Prov']
df = pd.read_csv('Ficheros/Manchas/SN_d_tot_V2.0.csv', sep = r'\s*;\s*', header = None, names = columns, na_values =[0, -1],
                engine = 'python')
df
# Out:
#        Year  Month  Day  Fraction  Spots  Stdev  Observ  Def/Prov
# 0      1818      1    1  1818.001    NaN    NaN     NaN       1.0
# 1      1818      1    2  1818.004    NaN    NaN     NaN       1.0
# 2      1818      1    3  1818.007    NaN    NaN     NaN       1.0
# 3      1818      1    4  1818.010    NaN    NaN     NaN       1.0
# 4      1818      1    5  1818.012    NaN    NaN     NaN       1.0
# ...     ...    ...  ...       ...    ...    ...     ...       ...
# 73834  2020      2   25  2020.152    NaN    NaN    25.0       NaN
# 73835  2020      2   26  2020.154    NaN    NaN    30.0       NaN
# 73836  2020      2   27  2020.157    NaN    NaN    28.0       NaN
# 73837  2020      2   28  2020.160    NaN    NaN    32.0       NaN
# 73838  2020      2   29  2020.163    NaN    NaN    23.0       NaN
#
# [73839 rows x 8 columns]

# %%
# Un poco de información
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73839 entries, 0 to 73838
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      73839 non-null  int64
#  1   Month     73839 non-null  int64
#  2   Day       73839 non-null  int64
#  3   Fraction  73839 non-null  float64
#  4   Spots     59396 non-null  float64
#  5   Stdev     67975 non-null  float64
#  6   Observ    70592 non-null  float64
#  7   Def/Prov  73687 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 4.5 MB

# %%
# Borramos las fechas anteriores a 1975, puesto que no nos interesan para el trabajo posterior
df.drop(df[df['Year'] < 1975].index, inplace = True)

# %%
# Controlamos los NaN
df.isna().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Fraction       0
# Spots       2270
# Stdev        875
# Observ         0
# Def/Prov     152
# dtype: int64

# %%
# Para evitar eliminar registros usaremos interpolación para rellenar los NaN en la columna "Spots"
df['Spots'] = df['Spots'].interpolate()

# %%
# Creamos una columna en formato fecha para operaciones posteriores
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# %%
# Tomaremos como outliers la media + 3Stdev (~325)
len(df[df['Spots'] > 325])
# Out:
# 114

# %%
# Los borramos
df.drop(df[df.Spots > 325].index, inplace =True)

# %%
# Solo nos interesan la nueva columna de fecha y el número de manchas (Spots). Eliminamos el resto
df.drop(['Year', 'Month', 'Day', 'Fraction', 'Stdev', 'Observ', 'Def/Prov'], axis = 'columns', inplace = True)

# %%
# Reordenamos
df = df[['Date', 'Spots']].reset_index()

# %%
# Lo guardamos para usarlo posteriormente
df.to_csv('Spots_new.csv', index = False)

# %% [markdown]
# # Flares

# %%
# En este caso nos encontramos un fichero por año, incluso algún año está "partido" en dos ficheros.
# Veamos uno de ellos
! cat "Ficheros/Flare/xray-flares_1992.txt" | head
# Out:
# 920701GO70318032403241.1E-083.4E-085.7E-04
# 920701GO70423043704371.6E-087.7E-081.7E-03
# 920701GO60424043704371.8E-086.5E-081.8E-03
# 920701GO70514052305238.2E-094.3E-081.4E-03
# 920701GO60721072607269.2E-092.8E-084.8E-04
# 920701GO70721072607269.4E-092.9E-084.4E-04
# 920701GO60757080408048.3E-093.8E-088.7E-04
# 920701GO70757080408046.7E-094.3E-088.2E-04
# 920701GO60935094009406.7E-094.1E-083.8E-04
# 920701GO70935094009403.4E-094.3E-083.6E-04
# cat: write error: Broken pipe

# %%
# Lo más práctico será unir todos en uno y tratar el resultado
! cat Ficheros/Flare/*.txt > flare_all.txt

# %%
# Veamos el fichero resultante
! cat flare_all.txt
# Out:
# SELDADS X-RAY Data for 2012-01-01
# 120101G150445045004574.5E-078.1E-074.4E-04
# 120101G150724073407447.4E-073.2E-062.8E-03
# 120101G151322132613335.2E-078.0E-074.1E-04
# 120101G151854185919065.5E-078.9E-074.9E-04
# 120101G152328233623466.5E-071.3E-061.1E-03
# 120102G150255030003075.2E-077.6E-074.3E-04
# 120102G150523052805347.3E-071.6E-067.8E-04
# 120102G150705072407325.2E-071.5E-061.6E-03
# 120102G150756080208095.2E-078.4E-075.1E-04
# 120102G150927093009324.2E-076.1E-071.0E-04
# 120102G151111111811264.5E-078.2E-075.8E-04
# 120102G151431152416045.1E-072.4E-068.7E-03
# 120103G150331033403384.4E-076.7E-071.8E-04
# 120103G150414041904274.6E-078.0E-074.7E-04
# 120103G152050205320554.3E-077.7E-071.1E-04
# 120104G150219022202264.5E-076.4E-071.8E-04
# 120104G150857090209055.0E-071.5E-064.6E-04
# 120104G151059110611144.8E-071.3E-068.2E-04
# 120105G150701072207435.2E-071.9E-063.8E-03
# 120105G151151123813005.1E-072.1E-066.6E-03
# 120106G150604060806117.2E-071.4E-063.6E-04
# 120106G151114112511355.5E-072.2E-062.0E-03
# 120106G151703170617094.9E-076.8E-071.5E-04
# 120106G151716171917224.6E-071.4E-062.6E-04
# 120106G152354000900238.0E-072.6E-063.6E-03
# 120107G150220023002388.3E-071.1E-061.2E-03
# 120107G150439045305078.1E-071.6E-062.2E-03
# 120107G151039104210477.0E-079.9E-073.3E-04
# 120108G150209022702461.3E-064.9E-068.7E-03
# 120108G150321032503291.6E-062.9E-069.4E-04
# 120108G150433043804497.2E-071.2E-069.4E-04
# 120108G150608061306168.7E-071.9E-065.7E-04
# 120108G151313131913257.1E-071.8E-069.3E-04
# 120108G151456150015028.8E-071.3E-062.9E-04
# 120108G151720172617336.9E-071.4E-068.1E-04
# 120108G151914191819265.0E-079.2E-074.9E-04
# 120108G152017202220384.7E-077.6E-077.5E-04
# 120109G151031104210476.8E-071.1E-069.2E-04
# 120109G151451145614585.4E-071.4E-063.7E-04
# 120109G151715171817219.4E-071.3E-062.9E-04
# 120109G152001201320287.7E-072.6E-063.2E-03
# 120110G150149015301565.2E-071.0E-062.6E-04
# 120110G150414041804244.7E-077.1E-073.2E-04
# 120110G152234230123127.7E-071.7E-063.0E-03
# 120111G150001001100237.3E-072.2E-062.1E-03
# 120111G150140014701556.6E-071.6E-061.1E-03
# 120111G150431044605096.4E-073.7E-065.8E-03
# 120111G151104111211197.4E-071.6E-061.2E-03
# 120111G151306131113295.1E-077.6E-078.8E-04
# 120111G152045205020547.2E-071.2E-064.8E-04
# 120112G150049005801065.2E-071.5E-061.0E-03
# 120112G150212022002285.1E-078.9E-076.9E-04
# 120112G150419042304275.9E-079.1E-073.0E-04
# 120112G150754100112166.8E-072.5E-063.2E-02
# 120112G151311132313331.4E-063.3E-063.5E-03
# 120113G150601060506086.2E-072.2E-065.6E-04
# 120113G150919092309264.9E-078.2E-072.2E-04
# 120114G150319033504036.6E-072.1E-064.6E-03
# 120114G151200120912201.8E-064.1E-063.9E-03
# 120114G151314131813205.7E-061.4E-053.0E-03
# 120114G151835184018439.8E-072.8E-068.2E-04
# 120114G152141215422109.4E-072.1E-063.0E-03
# 120114G152321232523307.5E-071.2E-064.6E-04
# 120115G150123013001389.9E-071.5E-061.1E-03
# 120115G150206020902131.5E-062.3E-066.3E-04
# 120115G150248025202591.4E-062.1E-061.1E-03
# 120115G151057110111036.6E-071.0E-062.3E-04
# 120115G152356235900058.0E-071.1E-064.4E-04
# 120116G150014001800228.9E-072.5E-067.7E-04
# 120116G150236044406461.3E-066.5E-067.5E-02
# 120116G150808081208182.7E-064.0E-061.8E-03
# 120116G151031103811221.7E-065.6E-061.2E-02
# 120116G152250231623571.3E-063.9E-069.9E-03
# 120117G150441045305077.6E-071.0E-051.1E-02
# 120117G151719172317257.5E-071.4E-062.9E-04
# 120117G151832183718406.2E-072.3E-066.2E-04
# 120117G152353235700035.3E-071.0E-064.4E-04
# 120118G150117012101265.4E-078.5E-073.2E-04
# 120118G150809081408185.7E-079.7E-073.7E-04
# 120118G150905091009175.2E-078.6E-074.7E-04
# 120118G150951095409564.8E-071.0E-061.7E-04
# 120118G151016103010459.0E-072.4E-063.2E-03
# 120118G151210123012338.1E-079.6E-071.3E-03
# 120118G151904191219277.0E-071.7E-051.5E-02
# 120118G152257232023336.2E-075.1E-067.4E-03
# 120119G150352035503576.4E-071.2E-062.0E-04
# 120119G151022102610316.1E-078.9E-073.5E-04
# 120119G151241125013007.9E-073.2E-062.6E-03
# 120119G151344160517507.3E-073.2E-052.7E-01
# 120120G151458150115046.3E-079.1E-072.0E-04
# 120120G152101211221225.4E-071.3E-061.3E-03
# 120120G152148233300366.5E-071.4E-061.3E-02
# 120121G151335134213478.7E-072.4E-061.2E-03
# 120121G152044212021435.4E-071.3E-063.5E-03
# 120122G150232025703062.0E-067.1E-061.0E-02
# 120122G150847085409017.2E-072.2E-061.3E-03
# 120122G151238125513471.0E-063.7E-061.3E-02
# 120122G151915191819206.0E-079.5E-071.4E-04
# 120122G152022202620315.7E-079.8E-073.7E-04
# 120122G152047205320599.8E-072.1E-061.1E-03
# 120123G150338035904341.1E-058.7E-052.0E-01
# 120123G151940201120266.6E-071.4E-062.8E-03
# 120124G150429043304376.4E-071.0E-063.4E-04
# 120124G150946095309596.3E-072.5E-061.3E-03
# 120124G151657170817106.9E-071.3E-067.1E-04
# 120126G150000000500108.0E-071.5E-066.6E-04
# 120126G150026003600596.8E-075.8E-067.6E-03
# 120126G150140014902001.7E-067.9E-066.8E-03
# 120126G150358054207037.7E-076.4E-064.6E-02
# 120126G151001101110211.2E-062.7E-062.6E-03
# 120126G152038204420519.6E-072.8E-061.5E-03
# 120126G152155220222101.0E-061.8E-061.3E-03
# 120127G150111012401325.7E-071.7E-061.6E-03
# 120127G150401041004268.1E-072.1E-062.6E-03
# 120127G150624064206531.0E-065.5E-066.6E-03
# 120127G151158120612165.4E-071.4E-061.1E-03
# 120127G151302130513096.5E-071.0E-062.8E-04
# 120127G151737183718568.3E-071.7E-043.2E-01
# 120128G151530153415406.8E-071.0E-064.7E-04
# 120130G150315032303303.1E-075.1E-073.7E-04
# 120130G150435044004432.9E-071.3E-063.9E-04
# 120130G152143214821542.6E-074.9E-072.3E-04
# 120131G150616062406413.0E-076.7E-078.0E-04
# 120131G151404141514283.6E-079.9E-071.0E-03
# SELDADS X-RAY Data for 2012-02-01
# 120201G150413044104552.5E-071.0E-061.6E-03
# 120201G150850091609372.3E-076.4E-071.5E-03
# 120202G150857090709173.4E-077.8E-077.2E-04
# 120202G151151115411562.8E-075.0E-077.8E-05
# 120202G151806181518213.0E-078.9E-075.8E-04
# 120203G150439044704523.0E-077.4E-074.1E-04
# 120205G150725072907341.6E-073.1E-071.1E-04
# 120205G151243124712511.5E-072.4E-078.0E-05
# 120206G150723073307464.3E-079.3E-071.0E-03
# 120206G151120112311302.6E-073.9E-071.7E-04
# 120206G151310131413193.7E-076.8E-072.5E-04
# 120206G151442144714523.8E-077.9E-073.2E-04
# 120206G151515151815213.5E-075.2E-071.1E-04
# 120206G151618162316263.5E-076.2E-072.0E-04
# 120206G151649165417123.1E-076.6E-077.3E-04
# 120206G151720172717374.1E-071.2E-069.6E-04
# 120206G151931200020176.6E-071.0E-051.9E-02
# 120207G150115012301306.3E-073.5E-062.1E-03
# 120207G150232023702422.4E-074.0E-071.8E-04
# 120207G150417042404473.3E-071.7E-062.4E-03
# 120207G151034103910424.0E-078.0E-072.6E-04
# 120207G151056110311113.9E-075.1E-062.8E-03
# 120207G151233123812523.1E-075.2E-074.8E-04
# 120207G151611173417423.7E-076.8E-067.0E-03
# 120207G152018221923211.8E-067.3E-065.4E-02
# 120208G150707071407224.0E-078.2E-075.6E-04
# 120208G152148221722282.8E-072.9E-065.2E-03
# 120209G150459050905143.9E-079.3E-076.2E-04
# 120209G150920093309505.6E-071.1E-061.7E-03
# 120209G151200121612284.3E-079.9E-071.3E-03
# 120209G152201220722173.6E-077.5E-075.4E-04
# 120210G150006002700473.5E-077.7E-071.5E-03
# 120210G150434043504374.1E-078.8E-071.5E-04
# 120210G150810081308152.7E-073.2E-071.1E-04
# 120210G151205121212192.9E-071.1E-066.3E-04
# 120210G151520153616004.8E-071.1E-062.2E-03
# 120210G151827183118334.4E-079.9E-072.0E-04
# 120210G152055210421194.8E-078.7E-071.1E-03
# 120210G152321232623304.0E-078.4E-073.0E-04
# 120210G152348235223544.1E-077.6E-071.6E-04
# 120211G150849085509015.5E-071.4E-067.5E-04
# 120211G150955100410115.0E-077.9E-065.0E-03
# 120211G151041104410496.9E-071.5E-064.6E-04
# 120211G151210121412184.3E-077.2E-072.3E-04
# 120211G151512152615323.3E-076.0E-075.7E-04
# 120211G151555160516093.7E-072.7E-061.3E-03
# 120211G151847185419065.4E-077.7E-065.1E-03
# 120211G151908191219204.3E-065.3E-063.9E-03
# 120211G152038204420503.8E-072.7E-061.2E-03
# 120211G152326233323363.2E-072.8E-068.0E-04
# 120212G150442044604513.4E-071.3E-064.6E-04
# 120212G150653070107052.5E-071.6E-066.6E-04
# 120212G150732073807462.6E-079.7E-075.4E-04
# 120212G151103110611083.3E-075.2E-078.3E-05
# 120212G151437144314463.7E-073.9E-061.2E-03
# 120212G151618162216243.6E-075.5E-071.2E-04
# 120212G151851185518582.7E-074.8E-071.2E-04
# 120212G152152215521573.0E-075.1E-077.7E-05
# 120212G152302231023132.3E-073.4E-071.7E-04
# 120212G152342234623492.4E-074.5E-071.2E-04
# 120213G150018002200262.4E-073.7E-071.2E-04
# 120214G151017102310271.8E-072.8E-071.6E-04
# 120214G151131114311512.0E-073.3E-073.3E-04
# 120214G151853185719001.9E-073.5E-079.2E-05
# 120214G152307232423371.9E-075.4E-077.1E-04
# 120215G150740074507511.9E-074.0E-071.9E-04
# 120218G151312131613211.8E-073.7E-071.4E-04
# 120219G150841085109003.8E-071.0E-068.7E-04
# 120219G151818182118282.1E-073.1E-071.4E-04
# 120219G151856190019022.3E-073.6E-078.0E-05
# 120219G151946194919552.4E-073.7E-071.4E-04
# 120220G150141014901582.2E-077.2E-075.1E-04
# 120220G150339034603522.9E-071.2E-065.9E-04
# 120220G150441050905353.2E-074.1E-069.1E-03
# 120220G151120112711323.8E-071.2E-065.7E-04
# 120220G152339235300033.5E-079.3E-071.0E-03
# 120221G151142114811556.1E-071.0E-066.2E-04
# 120221G151932193719412.7E-075.0E-071.9E-04
# 120221G152037204120453.1E-074.5E-071.5E-04
# 120224G150045004900553.1E-074.5E-072.0E-04
# 120224G151321132413302.9E-074.7E-071.8E-04
# 120225G151420150015152.8E-075.9E-071.5E-03
# 120225G151553155615583.2E-074.6E-077.6E-05
# 120225G152046205020582.4E-074.0E-072.1E-04
# 120225G152205221122162.5E-074.8E-072.3E-04
# 120226G150211021502182.7E-074.2E-071.2E-04
# 120226G150407041004142.4E-073.5E-079.7E-05
# 120226G150909095510331.5E-075.2E-071.9E-03
# 120226G151119112511343.7E-071.3E-068.7E-04
# 120226G152135214121492.4E-072.3E-061.2E-03
# 120226G152329233323352.3E-077.0E-071.3E-04
# 120227G151806181318223.9E-079.9E-076.9E-04
# 120228G150006001900322.1E-076.6E-077.8E-04
# 120228G150757080708141.7E-076.7E-074.6E-04
# 120229G150733073807411.5E-075.3E-071.5E-04
# 120229G151425142814341.6E-072.4E-079.4E-05
# 120229G151520152515551.7E-074.3E-076.9E-04
# 120229G152115212221283.7E-078.6E-074.9E-04
# 120229G152234224022512.7E-079.2E-076.5E-04
# SELDADS X-RAY Data for 2012-03-01
# 120301G150852101011161.7E-075.5E-072.7E-03
# 120301G151510152615362.8E-073.4E-063.0E-03
# 120302G150309031303213.2E-074.1E-073.0E-04
# 120302G151729174618078.9E-073.3E-054.9E-02
# 120302G152337234323544.7E-077.7E-076.4E-04
# 120303G150056010201276.7E-071.4E-062.1E-03
# 120303G150301030803117.2E-071.3E-065.6E-04
# 120303G150515052005256.4E-071.2E-065.3E-04
# 120303G150534060906376.6E-072.8E-066.9E-03
# 120303G151512151515172.7E-073.8E-076.3E-05
# 120303G151756180318056.3E-071.1E-064.3E-04
# 120303G151813194820467.5E-071.9E-061.0E-02
# 120304G150030003400374.5E-077.0E-071.9E-04
# 120304G150140014501484.9E-071.4E-064.3E-04
# 120304G150205021002133.8E-077.2E-072.3E-04
# 120304G150328033303384.4E-072.8E-061.1E-03
# 120304G150644065106597.6E-071.3E-069.4E-04
# 120304G151029105212165.6E-072.0E-059.2E-02
# 120304G151724173117351.2E-063.2E-061.4E-03
# 120305G150023003600471.0E-063.4E-063.4E-03
# 120305G150058010601191.6E-064.7E-064.5E-03
# 120305G150230040904431.3E-061.1E-043.7E-01
# 120305G151029103210361.6E-062.3E-066.3E-04
# 120305G151205121312211.1E-065.9E-063.4E-03
# 120305G151426142914339.0E-071.2E-063.6E-04
# 120305G151454150415099.8E-075.5E-063.1E-03
# 120305G151524152915331.2E-067.8E-062.4E-03
# 120305G151616162216262.5E-069.8E-063.4E-03
# 120305G151644165016522.4E-064.6E-061.4E-03
# 120305G151725172817381.0E-061.5E-069.3E-04
# 120305G151833183718411.1E-066.8E-061.9E-03
# 120305G151910191619211.3E-062.1E-057.8E-03
# 120305G151927193019323.6E-061.8E-052.7E-03
# 120305G152010201520171.0E-061.7E-064.4E-04
# 120305G152226223422421.1E-061.3E-057.3E-03
# 120305G152253225622591.3E-062.5E-065.2E-04
# 120305G152317232023251.1E-061.6E-065.5E-04
# 120305G152353000400091.4E-062.4E-061.9E-03
# 120306G150022002800311.5E-061.3E-053.7E-03
# 120306G150113011801251.2E-063.5E-061.9E-03
# 120306G150136014401501.7E-061.2E-055.9E-03
# 120306G150226023302371.3E-062.4E-061.1E-03
# 120306G150324032803312.8E-069.2E-062.2E-03
# 120306G150401040504082.6E-061.0E-052.6E-03
# 120306G150519052805311.5E-063.0E-061.4E-03
# 120306G150548055205581.6E-063.0E-061.3E-03
# 120306G150647065006531.3E-062.6E-065.3E-04
# 120306G150731074307471.3E-065.3E-063.2E-03
# 120306G150752075508003.2E-061.0E-052.7E-03
# 120306G151110111711221.4E-062.8E-061.5E-03
# 120306G151223124112541.6E-062.1E-052.2E-02
# 120306G151645165016541.1E-064.2E-061.3E-03
# 120306G151717172017221.1E-061.5E-062.5E-04
# 120306G151943194619491.4E-062.7E-065.5E-04
# 120306G152104211121142.2E-061.3E-054.9E-03
# 120306G152152215622111.2E-061.8E-061.7E-03
# 120306G152249225323114.0E-061.0E-059.7E-03
# 120307G150002002400403.4E-065.4E-046.7E-01
# 120307G150105011401231.1E-041.3E-041.5E-01
# 120307G151619162216269.8E-071.6E-064.3E-04
# 120308G150249025302568.1E-077.2E-061.5E-03
# 120308G151019102310266.8E-071.7E-064.0E-04
# 120308G151617162316278.0E-071.1E-066.7E-04
# 120308G151928193119341.0E-062.0E-064.2E-04
# 120308G151958202220338.7E-071.7E-062.2E-03
# 120308G152322232723315.7E-071.4E-064.9E-04
# 120309G150034003700467.4E-071.0E-066.0E-04
# 120309G150123012801347.7E-072.0E-069.3E-04
# 120309G150155020002069.1E-074.7E-061.9E-03
# 120309G150301030403088.2E-071.2E-063.3E-04
# 120309G150322035304187.9E-076.3E-051.3E-01
# 120309G151020102310261.5E-062.8E-065.6E-04
# 120309G151602160616109.6E-071.5E-065.1E-04
# 120309G151612161716261.1E-062.0E-061.3E-03
# 120309G151800180318051.1E-061.8E-062.9E-04
# 120309G151959202520491.1E-069.7E-062.0E-02
# 120309G152145215021561.6E-065.1E-062.3E-03
# 120310G150019011901451.0E-063.8E-061.4E-02
# 120310G150233023902451.9E-063.5E-061.9E-03
# 120310G150443044604507.9E-071.1E-063.2E-04
# 120310G150550055506011.0E-061.8E-068.9E-04
# 120310G150653070207067.3E-071.9E-061.0E-03
# 120310G150731074608017.3E-071.9E-062.8E-03
# 120310G150802080508091.3E-062.0E-065.4E-04
# 120310G151322132613297.3E-071.2E-063.2E-04
# 120310G151443155216166.8E-078.0E-062.1E-02
# 120310G151715174418302.1E-068.4E-052.6E-01
# 120311G150321032303262.2E-062.3E-068.4E-04
# 120311G150426042804321.4E-061.6E-066.6E-04
# 120311G150638064406469.1E-071.2E-065.9E-04
# 120311G150723072807358.4E-071.0E-067.4E-04
# 120311G151058110311136.7E-079.6E-078.2E-04
# 120311G151359140214047.0E-078.8E-072.9E-04
# 120312G150007001100148.3E-071.4E-063.8E-04
# 120312G150134015502081.0E-062.3E-063.8E-03
# 120312G151050105511014.7E-078.8E-074.3E-04
# 120312G151157120912197.0E-071.6E-061.7E-03
# 120312G152220003900564.7E-074.1E-061.5E-02
# 120313G150145015001567.2E-071.2E-066.0E-04
# 120313G150655072808357.2E-073.1E-061.5E-02
# 120313G151712174118253.4E-067.9E-052.4E-01
# 120314G151508152115367.3E-072.8E-052.9E-02
# 120315G150127013401396.9E-071.1E-066.5E-04
# 120315G150723075208085.8E-071.8E-052.2E-02
# 120315G151404141014155.8E-071.1E-065.6E-04
# 120315G151851185719004.1E-076.7E-072.6E-04
# 120316G150221023102437.8E-071.2E-061.5E-03
# 120316G150303030903176.5E-079.2E-077.6E-04
# 120316G150746075007533.8E-075.6E-071.5E-04
# 120316G150824082808333.4E-076.4E-072.4E-04
# 120316G151234124012453.7E-071.1E-065.3E-04
# 120316G151314131813212.8E-078.8E-072.2E-04
# 120316G151705173818003.0E-071.8E-064.4E-03
# 120316G152051210821212.6E-076.0E-077.9E-04
# 120317G150300031203182.1E-071.0E-067.0E-04
# 120317G150833112011591.1E-073.8E-072.2E-03
# 120317G151804181418252.9E-076.0E-076.1E-04
# 120317G152032203920422.2E-071.4E-053.6E-03
# 120317G152320234123551.8E-078.1E-071.3E-03
# 120318G150228023702446.2E-071.9E-061.3E-03
# 120318G150807081808323.4E-078.6E-079.7E-04
# 120318G151939194219472.3E-074.4E-071.4E-04
# 120318G152135213821452.0E-072.9E-071.3E-04
# 120318G152225222822322.0E-073.0E-078.2E-05
# 120318G152335234023432.0E-073.4E-071.1E-04
# 120319G150005000800102.4E-073.5E-075.4E-05
# 120319G150024002900312.4E-075.7E-071.4E-04
# 120319G150213021902232.6E-077.1E-072.7E-04
# 120319G150228023102353.9E-075.9E-071.6E-04
# 120319G150341034503484.0E-077.1E-071.9E-04
# 120319G150437044104443.3E-079.8E-072.4E-04
# 120319G150832110211071.0E-073.9E-071.1E-03
# 120319G151248130713152.8E-075.5E-076.7E-04
# 120319G151341135114133.6E-071.2E-061.7E-03
# 120319G151706170917112.8E-074.0E-076.6E-05
# 120319G152155220422162.9E-073.5E-063.0E-03
# 120320G150147015101542.4E-074.1E-071.1E-04
# 120320G151450145414572.7E-074.3E-071.2E-04
# 120320G152343000800383.5E-071.7E-063.9E-03
# 120321G150320032503322.9E-075.1E-072.7E-04
# 120321G150625062806312.5E-073.7E-078.1E-05
# 120321G150632064406523.3E-079.6E-078.7E-04
# 120321G150955100710122.5E-079.4E-076.7E-04
# 120321G151238125213013.1E-072.9E-062.2E-03
# 120321G151354135914043.0E-071.2E-064.7E-04
# 120321G151542155015564.1E-071.1E-066.5E-04
# 120321G151807181118172.3E-076.7E-072.7E-04
# 120323G151631163916432.6E-076.5E-062.1E-03
# 120323G151934194019443.1E-071.0E-053.0E-03
# 120323G152149215421583.1E-077.0E-072.5E-04
# 120323G152226222922313.2E-075.8E-079.0E-05
# 120323G152326232923312.6E-073.8E-076.2E-05
# SELDADS X-RAY Data for 2012-04-01
# 120402G150228023402413.9E-077.9E-074.5E-04
# 120402G152153222022532.5E-074.9E-071.5E-03
# 120403G151225122812352.6E-074.2E-071.9E-04
# 120403G151516153515502.4E-073.7E-076.6E-04
# 120403G152115212321382.8E-074.3E-075.5E-04
# 120404G150323035004031.8E-074.1E-077.2E-04
# 120404G150530055706311.7E-077.0E-071.8E-03
# 120404G151617162716512.5E-071.2E-061.9E-03
# 120405G151011103010492.7E-076.9E-071.2E-03
# 120405G151318132713412.6E-079.8E-079.9E-04
# 120405G151616162416322.2E-073.1E-061.7E-03
# 120405G152049211021573.7E-071.5E-065.1E-03
# 120405G152350000000055.4E-071.1E-068.0E-04
# 120406G150358040904252.0E-075.7E-077.3E-04
# 120407G150021002600351.9E-073.0E-072.0E-04
# 120407G150822082708351.4E-072.1E-071.3E-04
# 120407G150927093609412.3E-077.4E-074.2E-04
# 120407G151659170817152.8E-072.4E-061.4E-03
# 120407G151908195520164.6E-076.8E-072.5E-03
# 120408G150101010501112.4E-073.7E-071.6E-04
# 120408G150249025403012.3E-073.7E-072.1E-04
# 120408G151126112911323.7E-077.1E-071.5E-04
# 120408G151419142414271.3E-072.7E-078.2E-05
# 120408G151453154716071.5E-077.2E-071.9E-03
# 120408G151846185319002.8E-076.8E-074.1E-04
# 120408G152016202320291.7E-073.7E-072.2E-04
# 120408G152334234023491.4E-074.1E-072.6E-04
# 120409G150111012201311.9E-072.6E-061.9E-03
# 120409G150620062406411.9E-072.9E-073.1E-04
# 120409G150825082808331.2E-072.2E-077.2E-05
# 120409G151212124413085.0E-073.9E-069.2E-03
# 120410G150344034903541.4E-072.4E-071.0E-04
# 120410G151119112211241.4E-072.1E-073.4E-05
# 120410G151133113711401.5E-076.5E-071.5E-04
# 120411G151023103010391.4E-072.7E-072.0E-04
# 120412G150809084809171.8E-075.1E-071.7E-03
# 120412G150929093209342.9E-074.7E-077.8E-05
# 120412G152324232823301.6E-073.2E-076.8E-05
# 120413G150411042104391.9E-074.7E-076.4E-04
# 120413G150502050705123.5E-075.6E-072.5E-04
# 120413G151434143814472.0E-073.1E-071.9E-04
# 120413G152330233323392.3E-073.3E-071.3E-04
# 120414G150035004701022.0E-079.8E-071.1E-03
# 120414G150805081108183.2E-075.1E-073.1E-04
# 120414G152210221823062.3E-077.6E-071.9E-03
# 120415G150057014002052.7E-072.7E-066.0E-03
# 120415G150216023402451.1E-061.7E-062.9E-03
# 120415G150407042304364.4E-078.2E-071.2E-03
# 120415G150905090809105.6E-079.6E-071.6E-04
# 120415G152238224122462.5E-073.7E-071.2E-04
# 120416G150024004601083.2E-071.8E-063.7E-03
# 120416G151435144114452.7E-074.9E-072.1E-04
# 120416G151724174518003.0E-071.7E-052.5E-02
# 120417G150306031303232.9E-075.3E-074.3E-04
# 120417G150606080908523.2E-071.1E-069.2E-03
# 120417G151115112911503.6E-077.6E-071.3E-03
# 120417G152025203020324.7E-077.0E-071.9E-04
# 120417G152207222522383.2E-079.7E-071.2E-03
# 120418G150259030703104.0E-073.1E-061.0E-03
# 120418G150526053005334.9E-071.1E-062.7E-04
# 120418G150640064306455.9E-079.0E-071.4E-04
# 120418G150752080108363.8E-077.7E-071.7E-03
# 120418G150938094309515.7E-078.9E-075.5E-04
# 120418G151128114411544.8E-071.5E-061.8E-03
# 120418G151232123912506.1E-078.9E-066.1E-03
# 120418G151416142114254.6E-079.7E-073.4E-04
# 120418G151451151315184.4E-075.9E-063.4E-03
# 120418G151654170617188.3E-075.3E-065.5E-03
# 120418G151812181518208.9E-071.4E-064.5E-04
# 120418G152257230123045.4E-079.6E-072.6E-04
# 120419G150000001100186.8E-071.4E-061.2E-03
# 120419G150254030103056.0E-072.9E-061.1E-03
# 120419G150501050605166.2E-071.1E-067.8E-04
# 120419G151105112611447.2E-077.0E-069.1E-03
# 120419G151442151515267.6E-071.8E-064.0E-03
# 120420G150155020202095.2E-079.0E-075.9E-04
# 120420G150315032203285.5E-071.1E-066.7E-04
# 120420G151449150115326.9E-071.6E-063.3E-03
# 120420G151646164716491.6E-063.3E-065.9E-04
# 120420G151722172617361.0E-061.6E-061.1E-03
# 120420G152000200720105.9E-071.0E-064.3E-04
# 120420G152044204820518.2E-071.6E-064.4E-04
# 120420G152225223522446.7E-071.4E-061.3E-03
# 120421G150127013201347.6E-072.4E-065.6E-04
# 120421G151100111411246.2E-071.0E-061.3E-03
# 120421G151211121512226.0E-079.2E-074.6E-04
# 120421G152010201420199.9E-071.8E-066.8E-04
# 120422G150705070807107.7E-071.3E-062.2E-04
# 120422G150911091509227.6E-079.9E-076.6E-04
# 120422G150926092809308.6E-071.0E-062.9E-04
# 120422G151359140514138.0E-071.8E-061.1E-03
# 120422G151632163916488.3E-071.2E-061.1E-03
# 120422G151748175418006.1E-071.7E-068.2E-04
# 120422G152052205621007.8E-071.9E-066.0E-04
# 120422G152105211021179.8E-071.7E-069.2E-04
# 120422G152142214821531.2E-062.4E-061.1E-03
# 120423G150158020102038.3E-072.0E-063.1E-04
# 120423G150555055906035.2E-077.5E-072.5E-04
# 120423G150718072207265.3E-077.9E-072.6E-04
# 120423G151209121312156.1E-071.0E-062.2E-04
# 120423G151537154115455.9E-079.0E-073.0E-04
# 120423G151738175118056.0E-072.0E-062.5E-03
# 120424G150232023702425.6E-079.5E-074.2E-04
# 120424G150426043504445.7E-071.1E-069.7E-04
# 120424G150738074508006.6E-073.7E-063.6E-03
# 120424G151139115112026.1E-071.1E-061.3E-03
# 120424G151306131013135.2E-071.1E-063.0E-04
# 120424G151635164416566.5E-072.6E-062.3E-03
# 120424G152048205320586.9E-071.2E-065.5E-04
# 120425G150156022402316.5E-071.3E-062.1E-03
# 120425G150648065306565.6E-079.1E-073.1E-04
# 120425G150845085709005.4E-079.5E-076.1E-04
# 120425G151207121512195.4E-073.7E-061.6E-03
# 120425G152236224222506.6E-071.3E-068.5E-04
# 120426G151715172317304.8E-071.2E-068.0E-04
# 120426G152356001100316.2E-071.8E-063.2E-03
# 120427G150159020202056.0E-071.0E-062.2E-04
# 120427G150302030703185.7E-071.1E-068.2E-04
# 120427G150454050105095.3E-079.5E-076.8E-04
# 120427G150815082408291.1E-061.0E-055.3E-03
# 120427G151053110211081.8E-062.4E-062.1E-03
# 120427G151318132213279.1E-072.0E-067.5E-04
# 120427G152101210521099.6E-071.6E-065.2E-04
# 120427G152300230323069.0E-071.5E-063.2E-04
# 120427G152335233923438.6E-072.2E-066.8E-04
# 120428G150038004800537.9E-071.5E-061.0E-03
# 120428G150148015402007.3E-071.4E-067.8E-04
# 120428G150854090109046.6E-071.7E-067.0E-04
# 120428G151212121512184.8E-077.3E-071.6E-04
# 120428G151345141414346.0E-071.1E-062.9E-03
# 120428G152010201320168.9E-071.1E-064.3E-04
# 120428G152148221422246.8E-071.1E-061.9E-03
# 120429G150052005500575.0E-071.7E-062.3E-04
# 120429G150549055205544.4E-079.4E-071.5E-04
# 120429G151358140814158.5E-071.0E-061.0E-03
# 120429G151427143214389.8E-071.1E-067.9E-04
# 120429G151509151715248.3E-071.1E-069.8E-04
# 120429G151629163316396.9E-071.1E-064.9E-04
# 120429G151654165717006.3E-078.9E-072.0E-04
# 120430G150029003300354.5E-077.6E-071.7E-04
# 120430G150253025903025.0E-072.4E-066.9E-04
# 120430G150505050805124.6E-077.4E-072.0E-04
# 120430G150602060606104.8E-078.9E-072.7E-04
# 120430G150656073808194.5E-073.9E-061.5E-02
# 120430G150913091709211.0E-062.4E-067.6E-04
# 120430G151021102610327.1E-075.6E-062.2E-03
# 120430G151037104110432.4E-066.0E-061.1E-03
# 120430G151430143614414.8E-071.2E-065.6E-04
# SELDADS X-RAY Data for 2012-05-01
# 120501G150435044304473.7E-073.9E-061.6E-03
# 120501G150515054505525.8E-071.2E-062.2E-03
# 120501G151711171417173.8E-075.7E-071.2E-04
# 120501G151826183118364.6E-078.4E-073.6E-04
# 120501G152246225022528.7E-071.2E-062.8E-04
# 120502G150131013701415.1E-071.8E-067.0E-04
# 120502G151132113911464.1E-073.2E-061.7E-03
# 120502G151435144114464.6E-077.6E-073.7E-04
# 120502G151755180518135.5E-072.2E-061.6E-03
# 120502G151855190219119.9E-072.1E-061.5E-03
# 120502G152038205021027.8E-071.9E-062.2E-03
# 120503G150028010001183.8E-078.7E-072.0E-03
# 120503G150521052605375.5E-077.6E-077.1E-04
# 120503G151042110611233.6E-071.0E-061.6E-03
# 120503G151324143215115.2E-071.6E-067.8E-03
# 120503G151639165617236.0E-072.3E-064.8E-03
# 120504G150250025502594.8E-077.6E-072.9E-04
# 120504G150448045404584.1E-071.3E-065.0E-04
# 120504G150750075407584.2E-077.4E-072.4E-04
# 120504G151446145014571.0E-061.5E-067.6E-04
# 120504G151922192819329.4E-071.8E-067.5E-04
# 120504G151934193719401.1E-062.3E-064.7E-04
# 120504G152058210221041.1E-061.6E-065.9E-04
# 120504G152350235600021.0E-061.9E-061.0E-03
# 120505G150100010501099.3E-071.6E-066.3E-04
# 120505G150257030203051.0E-061.9E-066.3E-04
# 120505G150519052205337.0E-071.1E-067.0E-04
# 120505G150555063907018.0E-072.0E-066.3E-03
# 120505G150831083808428.1E-072.1E-068.7E-04
# 120505G150930093509406.5E-076.8E-062.5E-03
# 120505G151056105911011.4E-062.3E-063.9E-04
# 120505G151312131613181.7E-062.7E-065.7E-04
# 120505G151319132313291.7E-061.4E-055.5E-03
# 120505G151642164816516.5E-071.8E-066.6E-04
# 120505G151717172117258.1E-072.8E-068.3E-04
# 120505G151756180718161.7E-063.4E-063.3E-03
# 120505G151824182818301.8E-063.7E-068.0E-04
# 120505G152037211421176.1E-071.2E-062.5E-03
# 120505G152124212821317.8E-071.3E-063.5E-04
# 120505G152234223822407.1E-071.0E-062.3E-04
# 120505G152241224522498.4E-071.6E-065.2E-04
# 120505G152256230123048.7E-071.3E-053.6E-03
# 120505G152328233323361.2E-062.0E-066.6E-04
# 120506G150112011801206.6E-071.1E-052.3E-03
# 120506G150246025002557.7E-071.5E-065.6E-04
# 120506G150313032503371.0E-062.9E-063.3E-03
# 120506G150431043604436.7E-073.9E-061.7E-03
# 120506G150524053005507.0E-071.2E-061.5E-03
# 120506G150701070407076.9E-071.7E-063.3E-04
# 120506G151133114211476.4E-071.4E-068.7E-04
# 120506G151337134213468.4E-071.4E-065.4E-04
# 120506G151614162016235.7E-071.1E-064.1E-04
# 120506G151639165316595.4E-073.2E-062.1E-03
# 120506G151705170917121.5E-063.0E-067.8E-04
# 120506G151731173517371.6E-062.6E-065.6E-04
# 120506G151741174717521.4E-061.3E-054.4E-03
# 120506G151922192619321.0E-062.3E-069.5E-04
# 120506G152005201520207.2E-074.3E-062.5E-03
# 120506G152227223122387.2E-071.1E-065.7E-04
# 120506G152311231423217.1E-071.1E-065.1E-04
# 120507G150033003600398.6E-071.3E-063.0E-04
# 120507G150237025002591.4E-067.1E-065.8E-03
# 120507G150320032503299.8E-072.7E-069.6E-04
# 120507G150339034203457.9E-071.2E-062.6E-04
# 120507G150349035203548.1E-071.2E-062.1E-04
# 120507G150609062006256.6E-071.3E-069.5E-04
# 120507G150645070307087.3E-074.0E-063.0E-03
# 120507G150826083008339.1E-071.4E-063.8E-04
# 120507G151028103310376.1E-071.1E-064.2E-04
# 120507G151102110811116.2E-077.9E-062.2E-03
# 120507G151237124112456.6E-071.1E-063.6E-04
# 120507G151403143114527.8E-071.9E-053.5E-02
# 120507G151720172617305.7E-077.4E-062.5E-03
# 120507G152133213621415.2E-077.4E-072.5E-04
# 120508G150800080408073.8E-077.3E-071.9E-04
# 120508G150823083608404.1E-071.9E-061.1E-03
# 120508G150921092809314.5E-071.7E-065.9E-04
# 120508G151036103910421.1E-061.8E-063.9E-04
# 120508G151302130813124.5E-071.4E-054.5E-03
# 120508G151932193919443.5E-071.5E-066.6E-04
# 120508G152137214121433.1E-075.4E-071.2E-04
# 120509G150027003000323.1E-074.7E-077.8E-05
# 120509G150220022302263.8E-075.3E-071.2E-04
# 120509G150410041504203.5E-077.4E-073.1E-04
# 120509G150602060806153.7E-075.6E-073.5E-04
# 120509G150716072007223.9E-078.7E-071.8E-04
# 120509G150735073907424.8E-079.3E-072.4E-04
# 120509G150837084108436.3E-071.3E-062.9E-04
# 120509G150947095009524.8E-071.3E-061.7E-04
# 120509G151024102710314.7E-076.8E-071.9E-04
# 120509G151132113911454.4E-079.4E-075.4E-04
# 120509G151221123212366.7E-074.7E-051.9E-02
# 120509G151402140814149.7E-071.8E-057.5E-03
# 120509G151626164216454.9E-072.1E-061.3E-03
# 120509G151710171417174.4E-077.7E-072.0E-04
# 120509G151809181318165.7E-071.4E-063.7E-04
# 120509G151951195519589.5E-071.5E-064.2E-04
# 120509G152045205220556.2E-079.2E-062.8E-03
# 120509G152101210521091.1E-064.1E-051.2E-02
# 120509G152228223222368.8E-071.2E-064.2E-04
# 120509G152243224622497.3E-071.5E-063.0E-04
# 120509G152258230123046.3E-071.0E-062.3E-04
# 120509G152357000100044.6E-077.7E-072.1E-04
# 120510G150010001400164.9E-071.4E-062.5E-04
# 120510G150048005100535.4E-078.5E-071.4E-04
# 120510G150144014801527.5E-072.4E-066.6E-04
# 120510G150157020002049.5E-071.9E-065.1E-04
# 120510G150209021302167.7E-071.2E-063.4E-04
# 120510G150411041804237.7E-075.7E-052.1E-02
# 120510G150504051005162.8E-067.9E-064.0E-03
# 120510G150517052205255.2E-068.3E-062.7E-03
# 120510G150555060106061.3E-063.1E-061.5E-03
# 120510G150619062206291.2E-063.6E-061.4E-03
# 120510G150732073507387.0E-071.5E-063.0E-04
# 120510G150808081108145.9E-078.9E-071.9E-04
# 120510G151022103510395.9E-071.0E-067.8E-04
# 120510G151210121512216.2E-071.1E-065.4E-04
# 120510G151234123712428.4E-072.2E-066.6E-04
# 120510G151310131513268.9E-071.9E-061.4E-03
# 120510G151334134013441.0E-064.7E-061.5E-03
# 120510G151352135714011.9E-064.2E-061.6E-03
# 120510G151655165917049.8E-073.3E-061.2E-03
# 120510G151910191819287.8E-071.4E-061.2E-03
# 120510G152020202620306.3E-071.7E-055.6E-03
# 120511G150335034203466.4E-073.1E-061.3E-03
# 120511G150418042104275.8E-071.0E-063.7E-04
# 120511G150428043504397.3E-071.9E-068.4E-04
# 120511G150524052705307.2E-071.1E-062.4E-04
# 120511G150533053705416.6E-071.3E-064.2E-04
# 120511G150700070507186.6E-071.2E-061.1E-03
# 120511G150739074307458.0E-071.2E-062.7E-04
# 120511G150809081608207.0E-071.7E-068.1E-04
# 120511G150829083508516.9E-072.9E-062.8E-03
# 120511G150937094609528.2E-072.3E-061.4E-03
# 120511G151013101610197.3E-071.3E-062.8E-04
# 120511G151035104010425.4E-079.6E-072.6E-04
# 120511G151102112211335.1E-071.2E-061.6E-03
# 120511G151200120312059.3E-071.3E-062.1E-04
# 120511G151210121612258.1E-071.5E-061.0E-03
# 120511G151258131013141.1E-064.3E-063.1E-03
# 120511G151418142314258.1E-073.5E-067.7E-04
# 120511G151708171617205.5E-072.1E-068.1E-04
# 120511G151731173817467.7E-076.1E-063.6E-03
# 120511G151852185619009.1E-071.6E-065.3E-04
# 120511G151954201620388.6E-074.1E-067.4E-03
# 120511G152302234400331.2E-063.2E-061.3E-02
# 120512G150317032103266.1E-071.2E-064.2E-04
# 120512G150436043904437.1E-071.3E-063.3E-04
# 120512G150507051705236.2E-071.9E-061.3E-03
# 120512G150649065507004.7E-071.7E-067.6E-04
# 120512G150711071507197.1E-071.5E-065.0E-04
# 120512G150918092409306.5E-071.4E-067.7E-04
# 120512G151237124812515.6E-071.4E-067.3E-04
# 120512G151319132513374.7E-072.5E-061.8E-03
# 120513G150155020202095.6E-071.1E-067.1E-04
# 120513G150251025703025.5E-078.7E-074.4E-04
# 120513G150401040804157.6E-074.5E-062.4E-03
# 120513G150721081408207.4E-077.0E-066.4E-03
# 120513G152226223222434.7E-079.9E-077.9E-04
# 120514G150038004500523.9E-071.1E-066.5E-04
# 120514G150424042904354.2E-078.0E-073.8E-04
# 120514G150714073807435.3E-074.1E-063.2E-03
# 120514G150935093909464.4E-072.5E-069.5E-04
# 120514G151025102810315.7E-078.2E-071.8E-04
# 120514G151333133813424.9E-071.0E-063.8E-04
# 120514G151542154815524.1E-077.0E-073.0E-04
# 120514G151609161516204.2E-073.2E-061.3E-03
# 120514G151835184518564.4E-079.2E-079.3E-04
# 120514G151922192619315.9E-071.8E-066.1E-04
# 120514G152020202320285.7E-078.1E-072.7E-04
# 120514G152204220922195.1E-079.6E-076.7E-04
# 120514G152351000300135.4E-071.5E-061.6E-03
# 120515G150937094510046.9E-071.8E-062.3E-03
# 120515G151146115011555.7E-078.2E-073.2E-04
# 120515G151941194519475.6E-079.0E-072.0E-04
# 120515G151954195720005.7E-071.0E-062.2E-04
# 120515G152211221622184.9E-073.1E-065.7E-04
# 120516G150014001800216.8E-071.8E-064.3E-04
# 120516G150910092109331.1E-062.5E-062.8E-03
# 120516G151221122612305.2E-071.0E-064.0E-04
# 120517G150125014702141.9E-065.1E-059.9E-02
# 120517G151150115412008.0E-071.1E-065.2E-04
# 120517G151852190219377.2E-071.3E-063.1E-03
# 120517G151947195820179.6E-071.4E-061.6E-03
# 120517G152117213221447.4E-071.3E-061.9E-03
# 120517G152245230323256.3E-071.3E-062.6E-03
# 120518G150445045104554.9E-077.7E-074.3E-04
# 120518G150753082308397.7E-073.6E-067.4E-03
# 120518G151252131513345.9E-072.0E-064.1E-03
# 120518G151336134713551.4E-062.1E-062.3E-03
# 120518G151447145715116.4E-071.3E-061.6E-03
# 120518G151544155616145.8E-072.0E-062.8E-03
# 120518G151830185919215.4E-071.9E-064.1E-03
# 120518G152341235900225.0E-072.2E-064.2E-03
# 120519G150115012301314.6E-071.1E-068.2E-04
# 120519G151204121812313.9E-071.0E-061.3E-03
# 120522G150400040404103.3E-074.8E-072.1E-04
# 120522G150731073507383.1E-075.9E-071.6E-04
# 120523G150015002700353.8E-071.2E-061.1E-03
# 120523G150140014501492.8E-079.7E-073.2E-04
# 120523G151102110811154.2E-077.1E-074.3E-04
# 120524G151133113711436.4E-071.1E-064.9E-04
# 120524G151607161116154.8E-079.0E-072.9E-04
# 120524G151733173717396.0E-079.8E-072.1E-04
# 120524G151841184518495.2E-071.3E-064.3E-04
# 120524G151957200920148.1E-073.9E-061.1E-03
# 120525G150156020102057.3E-071.5E-065.7E-04
# 120525G151009101410225.8E-071.6E-069.0E-04
# 120525G151054110111085.7E-071.3E-068.0E-04
# 120525G151124112711336.6E-079.5E-073.7E-04
# 120525G151549155516054.5E-071.4E-061.0E-03
# 120525G151953195820005.5E-072.0E-064.3E-04
# 120525G152002200720097.3E-072.0E-064.4E-04
# 120525G152307231023127.6E-071.1E-061.8E-04
# 120526G150136013902195.3E-078.6E-071.9E-03
# 120526G150438044204444.8E-078.2E-071.7E-04
# 120526G150539054205444.1E-075.7E-078.7E-05
# 120526G150604060706093.8E-076.6E-079.7E-05
# 120526G150905091409184.2E-071.5E-067.2E-04
# 120526G151110111411184.5E-076.8E-072.3E-04
# 120526G151604161016134.6E-072.7E-068.7E-04
# 120526G151826182918323.9E-075.7E-071.3E-04
# 120526G151848185619033.3E-076.3E-074.3E-04
# 120526G152126212921323.8E-075.5E-071.2E-04
# 120526G152258230123033.8E-075.7E-079.0E-05
# 120527G150250025803053.2E-078.3E-075.4E-04
# 120527G150442055206323.7E-073.1E-061.3E-02
# 120528G150527053205432.9E-075.2E-074.0E-04
# 120528G151144114711502.1E-076.1E-071.2E-04
# 120528G151233124913102.3E-077.4E-071.3E-03
# 120528G151409141914362.9E-076.8E-079.0E-04
# 120529G150451045505002.2E-073.5E-071.3E-04
# 120530G150143022602543.5E-079.3E-073.0E-03
# 120530G150836085009076.5E-071.0E-061.9E-03
# 120530G151856190719205.2E-078.7E-071.1E-03
# 120530G152155215922036.7E-071.0E-063.4E-04
# 120531G150103012701405.7E-071.5E-062.5E-03
# 120531G150515054906176.0E-071.3E-064.1E-03
# 120531G150635064306477.9E-071.2E-067.8E-04
# 120531G151326143214466.6E-072.2E-066.8E-03
# 120531G151530153615411.1E-062.5E-061.2E-03
# 120531G151736174017427.5E-071.4E-063.0E-04
# 120531G152254231723226.2E-071.3E-061.5E-03
# 120531G152327233623488.4E-071.2E-061.4E-03
# SELDADS X-RAY Data for 2012-06-01
# 120601G150526053405418.9E-072.1E-061.4E-03
# 120601G150737074007437.3E-071.1E-062.5E-04
# 120601G151702171017166.8E-072.4E-061.4E-03
# 120601G151937194019431.1E-061.8E-064.0E-04
# 120601G152230224123021.3E-063.3E-065.2E-03
# 120602G150101010501088.9E-072.2E-065.9E-04
# 120602G150415043104556.8E-071.5E-063.1E-03
# 120603G151206120912111.1E-061.6E-062.7E-04
# 120603G151748175517575.2E-073.3E-057.0E-03
# 120604G150931093609384.1E-071.0E-062.6E-04
# 120604G151535154216054.6E-079.9E-071.5E-03
# 120604G151646165817166.0E-071.1E-061.8E-03
# 120605G150746075508084.4E-071.1E-061.2E-03
# 120605G151153115711594.7E-071.5E-062.5E-04
# 120605G151756175918025.5E-078.3E-071.8E-04
# 120605G152049205921091.0E-064.2E-063.4E-03
# 120605G152145215421577.1E-071.0E-067.2E-04
# 120605G152306231323265.6E-071.0E-069.9E-04
# 120606G150212021902265.5E-071.8E-061.0E-03
# 120606G151614162016256.1E-071.2E-066.0E-04
# 120606G151703170617116.2E-071.0E-063.4E-04
# 120606G151755180518106.6E-071.0E-068.2E-04
# 120606G151954200620138.1E-072.1E-051.3E-02
# 120606G152128213221488.6E-071.2E-061.4E-03
# 120606G152229223622417.4E-071.1E-067.4E-04
# 120606G152300230423117.9E-071.1E-067.2E-04
# 120606G152356000000057.1E-071.0E-065.4E-04
# 120607G150006001500278.8E-071.6E-061.8E-03
# 120607G150037004100441.1E-061.2E-065.6E-04
# 120607G150149015802066.8E-071.0E-061.0E-03
# 120607G150223023902557.0E-071.2E-062.2E-03
# 120607G150311032903367.7E-071.0E-061.4E-03
# 120607G150551055606106.9E-071.5E-061.3E-03
# 120607G151206121612269.9E-072.0E-061.9E-03
# 120607G151304130413041.0E-061.1E-066.5E-05
# 120607G151340134013461.2E-061.1E-065.4E-04
# 120607G151419142814377.3E-072.7E-062.0E-03
# 120607G151529154315551.0E-069.1E-069.1E-03
# 120607G151927193219356.4E-071.1E-063.7E-04
# 120607G151936194219459.0E-071.8E-066.6E-04
# 120608G150251030703226.9E-077.7E-068.5E-03
# 120608G150711071607185.5E-074.8E-068.3E-04
# 120609G150300030803205.6E-071.5E-061.4E-03
# 120609G151027103210378.6E-071.6E-066.7E-04
# 120609G151120113211351.8E-061.9E-055.7E-03
# 120609G151523152715318.5E-071.7E-065.5E-04
# 120609G151645165316569.1E-071.8E-056.5E-03
# 120609G151830183418369.0E-071.3E-062.9E-04
# 120609G152311231423166.1E-078.7E-071.3E-04
# 120610G150019002600325.4E-078.6E-075.3E-04
# 120610G150127020802206.9E-071.0E-063.0E-03
# 120610G150439045104596.7E-071.1E-061.1E-03
# 120610G150639064506506.7E-071.3E-055.0E-03
# 120610G151810181518215.4E-071.3E-066.3E-04
# 120610G151942195119586.0E-072.3E-061.5E-03
# 120610G152316232123255.3E-071.1E-064.2E-04
# 120611G150412042704436.4E-071.1E-061.9E-03
# 120611G151125112911356.2E-071.1E-065.0E-04
# 120611G151232123713066.4E-079.8E-071.7E-03
# 120611G151443144714526.2E-071.0E-064.0E-04
# 120611G151535154215501.0E-061.5E-061.1E-03
# 120611G151701170417081.0E-061.5E-064.3E-04
# 120611G151859190319116.9E-071.5E-068.0E-04
# 120611G152101210521101.0E-061.5E-066.0E-04
# 120612G150213021702205.7E-071.0E-062.6E-04
# 120612G150213021702205.7E-071.0E-062.6E-04
# 120612G150234023802496.3E-071.2E-068.3E-04
# 120612G150311031503197.4E-072.1E-066.2E-04
# 120612G150412042004227.8E-071.0E-065.8E-04
# 120612G150512051605247.2E-078.5E-076.3E-04
# 120612G150531053305358.6E-071.0E-062.9E-04
# 120612G150547055505597.7E-071.0E-067.5E-04
# 120612G150638064306481.0E-062.0E-068.4E-04
# 120612G150710071407167.9E-071.3E-062.9E-04
# 120612G150900091009158.4E-071.6E-061.1E-03
# 120612G151215121812206.9E-071.1E-061.8E-04
# 120612G151317132213305.7E-078.0E-076.0E-04
# 120612G151601173217429.2E-071.4E-066.8E-03
# 120612G151904190919127.6E-071.5E-066.0E-04
# 120612G152250231123198.2E-071.3E-062.0E-03
# 120612G152340235700058.2E-071.6E-061.8E-03
# 120613G150032003600381.0E-061.9E-064.0E-04
# 120613G150138014901567.1E-071.1E-061.0E-03
# 120613G150210022702357.8E-071.2E-061.6E-03
# 120613G150315032003319.2E-072.2E-061.5E-03
# 120613G150540062106316.6E-071.3E-063.1E-03
# 120613G150913091909247.7E-072.7E-061.2E-03
# 120613G150936093909419.6E-071.3E-062.3E-04
# 120613G151129131714311.3E-061.2E-057.5E-02
# 120613G151441144814596.1E-067.0E-067.8E-03
# 120613G151525152715305.5E-066.2E-062.1E-03
# 120613G151847185218571.7E-062.7E-061.2E-03
# 120613G151917192619551.5E-066.8E-061.2E-02
# 120613G152259230223059.7E-071.8E-065.6E-04
# 120613G152325000200219.4E-071.2E-064.0E-03
# 120614G150143014701507.2E-071.3E-063.6E-04
# 120614G150249025202548.6E-071.2E-062.1E-04
# 120614G150459050405098.7E-071.7E-067.2E-04
# 120614G150731073707421.1E-062.0E-061.0E-03
# 120614G150802080608101.0E-061.6E-065.4E-04
# 120614G151045105010569.2E-072.6E-061.2E-03
# 120614G151105111211221.6E-065.0E-063.7E-03
# 120614G151233123712391.1E-062.6E-065.1E-04
# 120614G151252143515561.3E-061.9E-051.2E-01
# 120614G152047205221022.4E-064.0E-062.9E-03
# 120615G150032005201061.8E-063.0E-065.3E-03
# 120615G151307132413336.7E-073.4E-063.7E-03
# 120615G151539155015547.1E-071.1E-068.3E-04
# 120615G151805181618271.0E-062.0E-062.2E-03
# 120616G150043004800504.5E-072.4E-065.4E-04
# 120616G150120012501345.9E-078.8E-075.9E-04
# 120616G150620062906354.8E-071.4E-069.0E-04
# 120616G151444145314599.8E-071.8E-061.3E-03
# 120616G151831183518405.2E-071.0E-063.7E-04
# 120617G151725172817313.8E-071.0E-062.1E-04
# 120617G151736174017466.2E-073.9E-061.5E-03
# 120617G151951195720024.7E-071.0E-064.6E-04
# 120617G152132213921475.7E-071.8E-061.2E-03
# 120617G152215221822207.9E-071.1E-061.9E-04
# 120617G152303230723115.1E-071.2E-063.6E-04
# 120617G152337234223455.9E-071.2E-063.6E-04
# 120618G150052005901046.1E-071.6E-068.0E-04
# 120618G150201020502084.8E-079.9E-072.5E-04
# 120618G150641071408014.3E-071.0E-064.0E-03
# 120618G152132213621394.6E-076.5E-072.7E-04
# 120619G150400044505234.0E-071.1E-064.7E-03
# 120619G151327133514113.9E-071.2E-062.5E-03
# 120619G151415141814288.4E-071.0E-068.3E-04
# 120619G151848185218563.5E-076.5E-072.0E-04
# 120620G150146020302233.6E-071.2E-062.0E-03
# 120620G150415042104304.6E-071.0E-066.7E-04
# 120620G150549055806103.7E-071.3E-061.1E-03
# 120620G150634064006454.0E-076.7E-073.2E-04
# 120620G151059110811255.4E-071.5E-061.8E-03
# 120620G151545155316003.6E-077.8E-075.2E-04
# 120620G151614162816375.6E-073.1E-062.8E-03
# 120621G151716181419152.3E-077.0E-073.8E-03
# 120623G150702075008441.7E-072.7E-061.2E-02
# 120625G151145115011581.9E-073.2E-071.9E-04
# 120625G151641164516531.7E-073.1E-071.7E-04
# 120625G151803181418221.8E-075.2E-074.5E-04
# 120625G151826184819452.7E-075.4E-072.3E-03
# 120625G152040204420524.3E-077.5E-073.9E-04
# 120625G152055205921055.3E-071.4E-065.7E-04
# 120625G152215222322294.0E-077.0E-074.6E-04
# 120625G152341000700292.8E-071.0E-062.1E-03
# 120626G150342035604012.1E-074.1E-073.6E-04
# 120626G150901091209262.4E-076.1E-077.3E-04
# 120626G151241125513062.5E-071.3E-061.4E-03
# 120626G151933194419564.9E-071.3E-061.3E-03
# 120627G150140015002003.1E-078.9E-078.2E-04
# 120627G150258030303104.4E-077.7E-074.2E-04
# 120627G150518052705354.7E-073.4E-062.2E-03
# 120627G150757080808181.0E-063.2E-063.0E-03
# 120627G151100110611126.0E-071.6E-068.1E-04
# 120627G151233123812404.1E-073.4E-066.6E-04
# 120627G151919192319285.0E-078.5E-073.2E-04
# 120628G150146015402044.8E-071.0E-068.9E-04
# 120628G150210021402166.9E-072.6E-065.4E-04
# 120628G150318032303334.1E-076.2E-074.4E-04
# 120628G150445045204555.2E-074.2E-061.0E-03
# 120628G150557060106043.6E-075.1E-071.4E-04
# 120628G150909092309274.6E-078.8E-077.1E-04
# 120628G151112111611183.6E-077.2E-071.4E-04
# 120628G151302130613083.1E-075.3E-071.1E-04
# 120628G151603160616084.1E-076.4E-071.0E-04
# 120628G151607161216155.0E-072.4E-054.8E-03
# 120628G151938194220161.2E-061.7E-063.9E-03
# 120628G152141214721495.7E-073.4E-068.4E-04
# 120629G150033003800415.4E-071.4E-064.1E-04
# 120629G150118012501283.6E-076.7E-061.8E-03
# 120629G150409041404164.4E-074.6E-068.4E-04
# 120629G150510051405284.2E-076.3E-075.7E-04
# 120629G150555055906014.5E-071.3E-062.5E-04
# 120629G150643064706507.8E-076.2E-061.3E-03
# 120629G150819082208249.5E-072.9E-064.2E-04
# 120629G150913092009226.5E-072.2E-054.4E-03
# 120629G151627163316435.4E-071.0E-067.6E-04
# 120629G151835184418506.2E-071.1E-067.6E-04
# 120629G152330233823493.6E-071.8E-061.5E-03
# 120630G150435043804404.5E-071.0E-061.3E-04
# 120630G150822083008378.0E-074.4E-062.5E-03
# 120630G150948095309567.5E-071.6E-064.9E-04
# 120630G151008101110155.7E-078.6E-072.4E-04
# 120630G151048105711026.3E-072.7E-061.5E-03
# 120630G151248125212546.0E-071.0E-051.7E-03
# 120630G151602161216295.0E-071.3E-061.7E-03
# 120630G151826183218341.3E-061.6E-053.3E-03
# 120630G152121212521276.5E-071.4E-063.0E-04
# SELDADS X-RAY Data for 2012-07-01
# 120701G150102010701104.9E-071.3E-063.7E-04
# 120701G150127013001324.4E-076.4E-071.1E-04
# 120701G150711071607209.3E-075.4E-061.8E-03
# 120701G151012102310406.8E-071.3E-061.9E-03
# 120701G151526153215371.3E-062.4E-061.1E-03
# 120701G151541154515521.5E-068.2E-063.6E-03
# 120701G151800180418067.8E-071.2E-062.6E-04
# 120701G151807181218159.1E-072.7E-068.2E-04
# 120701G151911191819215.9E-072.9E-058.5E-03
# 120702G150026003500405.9E-071.1E-054.6E-03
# 120702G150238024202446.3E-071.5E-062.9E-04
# 120702G150251025402575.8E-079.5E-072.0E-04
# 120702G150356040004035.1E-078.4E-072.3E-04
# 120702G150447045104566.7E-071.0E-064.1E-04
# 120702G150501050805147.1E-073.5E-061.8E-03
# 120702G150703070707109.5E-072.1E-065.6E-04
# 120702G150850085508581.2E-062.4E-067.4E-04
# 120702G151033103710419.2E-072.9E-068.1E-04
# 120702G151043105210571.3E-065.6E-052.7E-02
# 120702G151219122812421.1E-061.8E-062.2E-03
# 120702G151432144614526.4E-071.7E-061.6E-03
# 120702G151637164416521.0E-062.0E-061.4E-03
# 120702G151742175017541.1E-063.7E-061.7E-03
# 120702G151803181218229.4E-074.5E-063.6E-03
# 120702G151845185619022.0E-067.4E-065.0E-03
# 120702G151927193119349.4E-071.4E-063.9E-04
# 120702G151934194319471.1E-062.5E-061.4E-03
# 120702G151959200720131.4E-063.8E-051.8E-02
# 120702G152133213621381.2E-062.0E-062.8E-04
# 120702G152205221222151.0E-063.5E-061.2E-03
# 120702G152317233923469.3E-076.5E-065.5E-03
# 120702G152349235600032.8E-062.0E-051.1E-02
# 120703G150043004700499.8E-071.9E-063.7E-04
# 120703G150053005700599.4E-072.6E-065.2E-04
# 120703G150238024102441.3E-062.7E-065.6E-04
# 120703G150336034203481.1E-069.9E-064.5E-03
# 120703G150414041804208.7E-072.4E-064.6E-04
# 120703G150605060906121.4E-062.8E-067.3E-04
# 120703G151212121512181.1E-062.0E-064.3E-04
# 120703G151302130613091.3E-062.3E-066.1E-04
# 120703G151356135914022.1E-064.2E-069.0E-04
# 120703G151436144114435.0E-068.2E-062.3E-03
# 120703G151519152215242.8E-064.1E-066.6E-04
# 120703G151658170217092.1E-069.0E-063.8E-03
# 120703G152014201720192.1E-063.5E-065.6E-04
# 120703G152036204520511.9E-069.3E-065.6E-03
# 120703G152147215121541.8E-062.9E-067.9E-04
# 120703G152326233023362.1E-065.0E-061.9E-03
# 120704G150130014501491.6E-065.1E-064.1E-03
# 120704G150403041004213.0E-066.1E-065.0E-03
# 120704G150428043704454.3E-062.3E-051.6E-02
# 120704G150900090609093.1E-066.7E-062.5E-03
# 120704G150947095509573.7E-065.3E-051.4E-02
# 120704G151113111711192.6E-065.9E-061.2E-03
# 120704G151207122412322.2E-062.3E-052.0E-02
# 120704G151410141314172.6E-065.6E-061.4E-03
# 120704G151435144014422.3E-061.3E-052.7E-03
# 120704G151445144914524.9E-068.2E-062.2E-03
# 120704G151547155015523.3E-066.4E-061.0E-03
# 120704G151608161216152.9E-066.9E-061.6E-03
# 120704G151633163916483.5E-061.8E-051.2E-02
# 120704G151930193419371.9E-062.9E-068.2E-04
# 120704G152123212721292.8E-069.5E-061.6E-03
# 120704G152203220922154.0E-064.6E-052.0E-02
# 120704G152239224522473.8E-067.4E-062.2E-03
# 120704G152347235500026.4E-061.2E-058.1E-03
# 120705G150105011001157.0E-062.4E-059.0E-03
# 120705G150201020502324.1E-067.0E-061.1E-02
# 120705G150235024202475.5E-062.2E-059.7E-03
# 120705G150325033603395.3E-064.7E-051.4E-02
# 120705G150442044504494.3E-069.1E-062.3E-03
# 120705G150649065807054.8E-061.1E-058.5E-03
# 120705G150740074507484.6E-061.3E-053.8E-03
# 120705G150905090809113.4E-065.0E-061.1E-03
# 120705G150917092009244.1E-065.9E-061.6E-03
# 120705G151044104810503.6E-061.8E-053.2E-03
# 120705G151139114411494.5E-066.2E-051.8E-02
# 120705G151305131813322.2E-061.2E-051.5E-02
# 120705G151341135213585.6E-067.4E-067.2E-03
# 120705G151415141814202.8E-064.0E-066.7E-04
# 120705G151441144514503.7E-068.3E-063.0E-03
# 120705G151556155916012.4E-066.2E-069.3E-04
# 120705G151751175417572.6E-065.1E-061.1E-03
# 120705G151812182018242.8E-066.1E-063.0E-03
# 120705G151939194419532.9E-064.8E-063.1E-03
# 120705G152009201420283.1E-061.6E-051.3E-02
# 120705G152137214521513.1E-061.6E-058.6E-03
# 120705G152334233923412.1E-065.0E-061.2E-03
# 120706G150013002100242.1E-066.8E-062.7E-03
# 120706G150137014001424.5E-062.9E-054.1E-03
# 120706G150228023102373.4E-065.0E-062.0E-03
# 120706G150244025102585.4E-061.0E-056.7E-03
# 120706G150428043304372.3E-065.8E-062.0E-03
# 120706G150452045905243.6E-067.7E-061.2E-02
# 120706G150702070707102.7E-067.4E-062.0E-03
# 120706G150817082308274.4E-061.5E-055.3E-03
# 120706G150913091809292.1E-063.8E-062.9E-03
# 120706G151024102910326.5E-061.8E-055.2E-03
# 120706G151326133013323.4E-061.2E-052.1E-03
# 120706G151450150015123.0E-067.8E-067.7E-03
# 120706G151601160516103.2E-065.0E-062.0E-03
# 120706G151707171017152.4E-063.4E-061.1E-03
# 120706G151738174317483.4E-067.2E-062.9E-03
# 120706G151848185519052.1E-061.3E-058.3E-03
# 120706G151920192419264.0E-069.2E-061.9E-03
# 120706G152301230823144.1E-061.1E-044.3E-02
# 120707G150310031503233.2E-061.2E-056.7E-03
# 120707G150413041904274.2E-066.7E-064.5E-03
# 120707G150818082808393.2E-061.0E-059.6E-03
# 120707G151036104410491.9E-066.4E-063.4E-03
# 120707G151057110311072.3E-062.6E-058.3E-03
# 120707G151210121312151.4E-062.4E-063.9E-04
# 120707G151302130613091.7E-063.2E-068.3E-04
# 120707G151310131413162.1E-063.9E-068.0E-04
# 120707G151345134913521.8E-063.7E-069.6E-04
# 120707G151433143614381.8E-063.0E-064.7E-04
# 120707G151442144714541.8E-063.6E-061.9E-03
# 120707G152356000900161.7E-068.4E-065.6E-03
# 120708G150203020902142.0E-063.6E-061.8E-03
# 120708G150328033203352.7E-064.4E-061.2E-03
# 120708G150414041904242.4E-066.6E-062.5E-03
# 120708G150528053405403.2E-065.9E-063.2E-03
# 120708G150541054605524.8E-061.3E-056.0E-03
# 120708G150621062506282.0E-066.8E-061.7E-03
# 120708G150944095309571.7E-061.1E-054.4E-03
# 120708G151021103010392.5E-066.9E-065.5E-03
# 120708G151044105010564.4E-065.4E-063.9E-03
# 120708G151206121012132.2E-061.4E-053.3E-03
# 120708G151254130213132.1E-066.1E-065.3E-03
# 120708G151435144314551.7E-066.7E-065.4E-03
# 120708G151623163216422.1E-066.9E-054.5E-02
# 120708G151729173417474.3E-068.8E-067.5E-03
# 120708G151748180318096.5E-069.2E-061.0E-02
# 120708G151921192419284.5E-066.6E-061.8E-03
# 120709G150706071307222.5E-064.5E-063.4E-03
# 120709G150805083008583.4E-067.9E-062.2E-02
# 120709G150921093210055.4E-066.5E-061.9E-02
# 120709G151946195219561.7E-065.0E-062.0E-03
# 120709G152207221722281.3E-062.2E-062.4E-03
# 120709G152303230723111.6E-061.1E-052.8E-03
# 120710G150337034303481.6E-063.9E-061.8E-03
# 120710G150431043904452.1E-067.0E-064.0E-03
# 120710G150458051405312.0E-061.7E-052.4E-02
# 120710G150605062706472.8E-062.1E-053.3E-02
# 120710G150816083408382.2E-064.5E-064.9E-03
# 120710G150900090409081.6E-064.1E-061.3E-03
# 120710G151208122412311.2E-065.5E-064.8E-03
# 120710G151237124412492.5E-064.6E-062.5E-03
# 120710G151339134513491.6E-068.2E-062.9E-03
# 120710G151527154515501.3E-065.6E-064.0E-03
# 120710G152007201420161.2E-063.2E-061.2E-03
# 120710G152357000900231.3E-063.0E-063.8E-03
# 120711G150526053305381.4E-063.4E-061.7E-03
# 120711G150824083108379.4E-079.9E-064.5E-03
# ...
# 110221G150500050605084.4E-074.1E-069.2E-04
# 110221G150602061006143.5E-074.3E-061.5E-03
# 110221G150901090609093.8E-072.7E-066.4E-04
# 110221G151000100410073.3E-071.8E-064.0E-04
# 110221G151008101210158.3E-077.8E-061.7E-03
# 110221G151539154415552.9E-070.099841.0E-03
# 110221G151825183518476.6E-071.4E-061.6E-03
# 110222G151033104811121.8E-076.5E-071.2E-03
# 110222G151215121912222.2E-073.5E-079.7E-05
# 110222G151434143814421.8E-072.6E-079.0E-05
# 110223G150935093909472.1E-073.1E-071.8E-04
# 110223G151024102810332.5E-073.7E-071.4E-04
# 110223G151110111811253.3E-076.0E-074.2E-04
# 110223G151215122312292.8E-071.2E-066.2E-04
# 110224G150249025302572.4E-073.9E-071.3E-04
# 110224G150723073507424.1E-073.5E-052.0E-02
# 110224G151347135313562.6E-070.099825.5E-04
# 110224G151712174017512.7E-078.5E-076.4E-04
# 110224G151820182318414.0E-075.9E-076.3E-04
# 110224G151856190019085.1E-079.1E-074.8E-04
# 110224G151934193819436.1E-072.7E-069.3E-04
# 110224G151950195319585.7E-079.2E-073.1E-04
# 110225G150138014201453.1E-074.8E-071.3E-04
# 110225G150322032503332.8E-074.2E-072.1E-04
# 110225G150515051805224.4E-071.4E-063.4E-04
# 110225G150540054405464.9E-071.6E-062.8E-04
# 110225G151053105811073.8E-076.2E-074.1E-04
# 110225G151718172917372.9E-071.1E-069.6E-04
# 110225G151857190119042.7E-074.5E-071.3E-04
# 110225G152229223322463.5E-075.2E-074.5E-04
# 110226G150007001000122.8E-074.3E-077.0E-05
# 110226G150054005901032.7E-079.0E-072.9E-04
# 110226G150118012101233.2E-074.6E-077.5E-05
# 110226G150503052005393.3E-078.9E-071.5E-03
# 110226G150732073507382.8E-074.5E-079.9E-05
# 110226G150809081308152.2E-071.3E-062.7E-04
# 110226G150935093909432.5E-073.7E-071.3E-04
# 110226G151434161516422.4E-078.3E-074.7E-03
# 110226G151920192419261.9E-073.9E-078.1E-05
# 110226G152046205020521.8E-074.3E-078.5E-05
# 110226G152323233023412.4E-075.7E-074.7E-04
# 110227G150041005901143.5E-077.3E-071.2E-03
# 110227G150349035503581.9E-074.2E-061.1E-03
# 110227G150504051105151.9E-072.7E-071.4E-04
# 110227G150755075708001.9E-072.8E-071.1E-04
# 110227G151430144214491.6E-076.1E-074.8E-04
# 110227G151547155315592.2E-077.2E-073.4E-04
# 110227G151714171817221.6E-072.9E-079.2E-05
# 110227G152117213421432.8E-077.7E-078.5E-04
# 110227G152221222422264.4E-076.8E-071.1E-04
# 110228G150144015001552.3E-075.0E-072.4E-04
# 110228G150210021402182.3E-075.0E-071.6E-04
# 110228G150417042804342.8E-077.9E-075.8E-04
# 110228G150524053305403.9E-071.7E-061.2E-03
# 110228G150630063806492.6E-071.1E-069.1E-04
# 110228G150701071007163.8E-070.099791.1E-03
# 110228G150734073807402.9E-072.4E-064.3E-04
# 110228G150938095210033.2E-071.5E-061.5E-03
# 110228G151025102910373.4E-075.5E-072.9E-04
# 110228G151202120712183.0E-071.2E-069.1E-04
# 110228G151238125213033.3E-071.1E-059.1E-03
# 110228G151544155215593.4E-071.0E-066.6E-04
# 110228G152011201620194.2E-077.3E-072.4E-04
# 110228G152115213121464.7E-070.099832.2E-03
# 110228G152311000500273.6E-071.6E-064.0E-03
# 110401G150146015602074.0E-073.4E-063.0E-03
# 110401G150348035403595.5E-073.1E-061.2E-03
# 110401G152219222322263.3E-076.8E-072.7E-04
# 110402G150322032603293.1E-074.6E-071.3E-04
# 110402G151433143814422.3E-074.1E-071.6E-04
# 110402G152234234723552.9E-078.3E-072.9E-03
# 110404G150307044705174.5E-078.6E-075.6E-03
# 110404G151710171317153.4E-075.5E-079.0E-05
# 110404G152319232523393.0E-075.2E-075.0E-04
# 110406G151546154915526.3E-079.6E-072.1E-04
# 110406G151614162316358.0E-071.2E-061.4E-03
# 110406G151712172017307.1E-079.4E-079.9E-04
# 110406G151752180718296.6E-071.9E-063.4E-03
# 110406G152135214521547.2E-071.4E-061.3E-03
# 110407G150419043504474.8E-071.8E-062.3E-03
# 110407G150454045905038.9E-070.099855.7E-04
# 110407G151625163916544.7E-071.5E-062.0E-03
# 110408G151816182418322.8E-077.4E-075.1E-04
# 110409G150040005001003.0E-078.0E-077.4E-04
# 110409G150157020202063.0E-074.2E-072.2E-04
# 110409G150357040004033.0E-074.4E-079.4E-05
# 110409G151448154515583.3E-071.3E-063.4E-03
# 110409G152301230423083.1E-075.0E-071.4E-04
# 110410G150006001000162.8E-074.3E-071.9E-04
# 110410G151606161216242.5E-075.1E-074.3E-04
# 110410G151753175818032.6E-074.4E-071.9E-04
# 110411G150909092109384.0E-079.2E-071.3E-03
# 110411G151249131013263.2E-077.2E-071.3E-03
# 110411G151553160216194.5E-071.2E-061.4E-03
# 110411G151652165717003.7E-074.6E-072.2E-04
# 110411G152025203020404.1E-071.8E-061.1E-03
# 110411G152211222422414.6E-078.1E-071.3E-03
# 110411G152340000000035.4E-072.5E-061.7E-03
# 110412G150340034603524.6E-071.7E-067.8E-04
# 110412G150546060706114.1E-073.1E-067.3E-04
# 110412G151221123212386.1E-071.8E-061.5E-03
# 110412G151752175818024.4E-079.7E-074.0E-04
# 110413G150321033003365.7E-071.9E-061.1E-03
# 110413G150625062806326.0E-072.2E-065.4E-04
# 110413G150755075908036.2E-071.2E-063.9E-04
# 110413G150829083208366.9E-070.099892.9E-04
# 110413G151037104110457.0E-071.4E-064.4E-04
# 110413G151312134313496.8E-072.5E-062.9E-03
# 110413G151602160716117.2E-071.1E-064.3E-04
# 110413G151904191119156.0E-071.5E-067.1E-04
# 110413G152006200920116.3E-079.1E-071.5E-04
# 110413G152252225923154.3E-079.3E-071.0E-03
# 110414G150041004800576.7E-071.5E-061.1E-03
# 110414G150131013501385.9E-071.4E-063.8E-04
# 110414G150249025803236.9E-072.0E-063.3E-03
# 110414G150520052705335.4E-074.9E-062.1E-03
# 110414G150615061806206.0E-078.5E-071.4E-04
# 110414G150656070007067.8E-070.099846.5E-04
# 110414G150938094409491.0E-062.3E-061.1E-03
# 110414G151226122912321.1E-061.6E-063.7E-04
# 110414G151521152715349.3E-072.4E-061.3E-03
# 110414G151707171017136.4E-070.099892.4E-04
# 110414G151837184018435.7E-079.8E-072.1E-04
# 110414G151856185919015.4E-078.2E-071.3E-04
# 110414G151957200820124.7E-071.7E-067.7E-04
# 110414G152017202020226.1E-079.3E-071.5E-04
# 110414G152111211821276.1E-071.1E-068.2E-04
# 110415G150243024702526.5E-078.8E-074.8E-04
# 110415G150343035504009.2E-071.8E-061.5E-03
# 110415G150437044104446.8E-070.099873.5E-04
# 110415G150809081108127.0E-071.1E-062.1E-04
# 110415G150910093609496.9E-071.6E-063.0E-03
# 110415G151129113611488.0E-071.9E-061.7E-03
# 110415G151347135013548.3E-072.8E-066.8E-04
# 110415G151442144914578.4E-070.099981.3E-03
# 110415G151608161416199.5E-070.099847.8E-04
# 110415G151702171217288.1E-071.3E-051.2E-02
# 110415G152233223622391.3E-061.8E-066.8E-04
# 110416G150034005701081.0E-065.2E-066.6E-03
# 110416G150154020102079.2E-071.4E-061.0E-03
# 110416G150231031203307.6E-072.1E-065.8E-03
# 110416G150401040804176.6E-071.4E-061.1E-03
# 110416G150526053805451.0E-063.5E-062.7E-03
# 110416G150606061506248.7E-071.7E-061.6E-03
# 110416G150900090709127.9E-071.8E-069.5E-04
# 110416G151032103610406.2E-079.4E-073.1E-04
# 110416G151351141414291.0E-065.7E-069.6E-03
# 110416G151611161416174.8E-076.8E-071.5E-04
# 110416G151634165317087.3E-073.7E-064.4E-03
# 110416G151959201720285.0E-071.0E-063.6E-03
# 110416G152052210221265.7E-079.0E-071.7E-03
# 110416G152316232523308.1E-071.7E-061.1E-03
# 110417G150538054105434.2E-077.1E-071.1E-04
# 110417G150802080608115.0E-078.0E-073.0E-04
# 110417G151408141514235.6E-071.4E-069.6E-04
# 110417G151529154016014.2E-077.4E-071.3E-03
# 110417G151629164917004.8E-077.2E-071.2E-03
# 110417G151900191819335.2E-071.3E-062.1E-03
# 110418G150235024302474.6E-070.099818.8E-04
# 110418G150332034804169.2E-071.8E-064.2E-03
# 110418G151052105611024.3E-076.6E-072.9E-04
# 110418G151556160216063.8E-079.7E-074.0E-04
# 110418G151855190219085.5E-070.099858.6E-04
# 110418G151917192419315.5E-071.0E-066.8E-04
# 110418G152312231523195.1E-077.6E-072.1E-04
# 110419G150234023702405.4E-077.8E-071.7E-04
# 110419G150508051205175.9E-071.0E-063.9E-04
# 110419G151116112011244.3E-079.0E-072.8E-04
# 110420G150346043104494.3E-071.0E-062.7E-03
# 110420G150924092809324.3E-076.7E-072.2E-04
# 110420G151307131113135.4E-078.5E-071.9E-04
# 110420G151738183619065.0E-071.5E-065.8E-03
# 110420G151930193919496.9E-074.0E-063.1E-03
# 110420G152302231623215.0E-078.9E-078.3E-04
# 110421G150624063906445.0E-078.3E-078.7E-04
# 110421G150831083808505.9E-071.0E-069.5E-04
# 110421G150938094809587.8E-078.5E-066.5E-03
# 110421G151437145115006.4E-074.9E-064.0E-03
# 110421G152151220722391.3E-064.5E-061.0E-02
# 110422G150013002000269.6E-071.5E-061.1E-03
# 110422G150435045705141.5E-061.8E-052.9E-02
# 110422G150708073207351.1E-060.099812.5E-03
# 110422G150804080908121.5E-062.5E-068.6E-04
# 110422G150940094609597.7E-072.6E-062.2E-03
# 110422G151107112511379.6E-077.7E-068.1E-03
# 110422G151229123612396.6E-073.0E-069.9E-04
# 110422G151404140714097.2E-071.3E-062.2E-04
# 110422G151442144714497.7E-071.3E-063.5E-04
# 110422G151455145915027.6E-071.4E-063.7E-04
# 110422G151547155316117.7E-071.2E-051.1E-02
# 110422G151656170717141.4E-065.5E-063.4E-03
# 110422G151741175418071.2E-064.2E-064.8E-03
# 110422G151930193519409.2E-073.6E-061.5E-03
# 110422G152054205721015.2E-079.5E-072.4E-04
# 110422G152147215922096.1E-072.7E-062.7E-03
# 110422G152239224622541.2E-062.4E-061.7E-03
# 110422G152255230023051.6E-062.9E-061.2E-03
# 110423G150152020002074.9E-071.3E-069.0E-04
# 110423G150243024702504.5E-078.6E-072.1E-04
# 110423G150309031303244.1E-076.0E-074.4E-04
# 110423G150339035304004.6E-070.099981.6E-03
# 110423G150414041904215.5E-070.099882.9E-04
# 110423G150451045905046.5E-071.2E-067.1E-04
# 110423G150730073407384.4E-072.4E-066.8E-04
# 110423G151028103210363.4E-075.5E-071.8E-04
# 110423G151243125213074.8E-078.1E-079.6E-04
# 110423G151409142214325.3E-071.0E-061.2E-03
# 110423G151604160716114.4E-076.2E-071.7E-04
# 110423G151858190319084.2E-076.7E-073.0E-04
# 110424G151913192619375.8E-072.4E-062.5E-03
# 110425G150233032203564.0E-078.7E-073.6E-03
# 110425G151601160616084.3E-078.1E-072.1E-04
# 110425G152212221922273.8E-079.3E-076.1E-04
# 110426G152210221622222.7E-074.4E-072.4E-04
# 110427G150226023303011.0E-062.0E-063.5E-03
# 110427G150613061706275.2E-078.7E-075.6E-04
# 110427G151357140014033.1E-074.5E-079.9E-05
# 110427G152254230423234.2E-078.0E-071.1E-03
# 110428G150232024002462.7E-071.0E-066.0E-04
# 110428G150859090309122.7E-074.4E-072.6E-04
# 110428G150915092209353.6E-076.7E-076.4E-04
# 110428G151002101910283.5E-078.3E-079.6E-04
# 110428G151041104710524.0E-078.0E-073.8E-04
# 110428G151151115812034.1E-072.4E-069.9E-04
# 110428G151239124712513.9E-070.099895.0E-04
# 110428G152106211221183.1E-078.2E-074.0E-04
# 110429G150017002600333.6E-073.8E-062.2E-03
# 110429G150126012901314.8E-078.9E-071.3E-04
# 110429G150851085408593.2E-074.9E-071.6E-04
# 110429G151244124812562.8E-076.6E-073.5E-04
# 110429G152040204820583.6E-071.8E-061.4E-03
# 110429G152249225523005.3E-071.5E-066.9E-04
# 110430G150414042004244.2E-077.6E-073.3E-04
# 110430G150505050805114.4E-076.8E-071.5E-04
# 110430G150811081908284.2E-071.5E-061.1E-03
# 110430G150855090409083.9E-071.7E-068.6E-04
# 110430G151132115111595.6E-073.2E-062.9E-03
# 110430G151219122812426.1E-071.0E-061.2E-03
# 110430G151308132614207.6E-070.099671.2E-02
# 110430G152154215722004.4E-076.3E-071.4E-04
# 110430G152209221222154.4E-076.6E-071.4E-04
# 110501G150751081408423.6E-071.6E-063.9E-03
# 110501G150949095710044.5E-079.9E-076.5E-04
# 110501G151158120112063.0E-076.6E-072.0E-04
# 110501G151237125013063.4E-075.8E-078.9E-04
# 110501G152325233223394.9E-076.5E-063.9E-03
# 110502G150713071607223.2E-074.7E-071.9E-04
# 110502G150950095710033.2E-075.7E-073.5E-04
# 110502G151349135213553.6E-076.0E-071.3E-04
# 110502G151401140514073.8E-070.099882.4E-04
# 110502G152200220422114.2E-076.1E-073.1E-04
# 110503G150012001600193.9E-077.0E-071.9E-04
# 110503G150354035904083.8E-079.1E-075.6E-04
# 110503G150620062506354.0E-076.3E-074.5E-04
# 110503G151047105210563.7E-071.3E-064.8E-04
# 110503G151844184818572.6E-074.1E-072.5E-04
# 110504G150144015102002.9E-079.3E-076.4E-04
# 110504G151056110411112.6E-074.5E-073.2E-04
# 110504G151655173818252.7E-076.8E-073.1E-03
# 110505G150842084508482.0E-073.0E-076.7E-05
# 110505G151742174617502.0E-072.9E-079.9E-05
# 110505G152037204320512.2E-074.2E-072.7E-04
# 110506G150308031203152.5E-073.8E-071.1E-04
# 110506G150850085308551.9E-072.9E-074.6E-05
# 110506G152219222222261.8E-072.6E-077.4E-05
# 110507G151530153815491.9E-073.3E-073.1E-04
# 110508G151001100810131.9E-074.3E-072.3E-04
# 110509G150426043004333.3E-075.6E-071.6E-04
# 110509G150511051605182.6E-071.4E-062.7E-04
# 110509G151319132513473.3E-077.1E-079.4E-04
# 110509G151731174117486.9E-071.5E-061.2E-03
# 110509G152042205921196.9E-075.4E-068.4E-03
# 110511G150223024303232.4E-078.1E-072.4E-03
# 110511G152028203620542.0E-073.2E-074.3E-04
# 110512G151211123612482.6E-072.0E-063.0E-03
# 110513G151348135514001.2E-072.2E-071.2E-04
# 110513G152135214021501.2E-072.2E-071.5E-04
# 110514G150057005801001.4E-072.1E-074.2E-05
# 110514G151143114711521.2E-071.8E-077.5E-05
# 110515G150438044204461.3E-071.9E-076.7E-05
# 110515G150735073907421.5E-072.5E-076.9E-05
# 110515G151304130813121.8E-073.0E-071.0E-04
# 110515G151411142514302.0E-071.3E-067.3E-04
# 110515G151616162016221.8E-075.6E-071.0E-04
# 110515G151739174317454.7E-078.4E-071.8E-04
# 110515G152325233423411.7E-074.8E-062.6E-03
# 110516G151031104010492.4E-075.7E-074.7E-04
# 110516G152211221922271.7E-073.5E-072.8E-04
# 110516G152319232323272.0E-073.0E-071.0E-04
# 110517G150104010901121.8E-073.5E-071.1E-04
# 110517G150140014301481.8E-072.6E-078.8E-05
# 110517G150235024302481.9E-074.1E-072.3E-04
# 110517G150858090509091.5E-072.2E-071.3E-04
# 110517G151127114412021.4E-072.7E-074.8E-04
# 110517G152015202320382.5E-075.3E-076.0E-04
# 110518G150056010001051.7E-072.4E-079.5E-05
# 110518G150525053305441.7E-072.7E-072.8E-04
# 110518G151157120112031.4E-072.3E-074.9E-05
# 110518G151248125913071.7E-071.2E-068.1E-04
# 110518G151633163716411.5E-072.0E-071.0E-04
# 110518G151802183019502.5E-072.0E-069.6E-03
# 110519G150159020302051.4E-072.0E-074.6E-05
# 110519G150209021302151.6E-073.5E-077.0E-05
# 110519G150349043605401.5E-073.0E-071.7E-03
# 110519G150938093909401.4E-072.2E-073.5E-05
# 110521G150735074207497.0E-081.6E-079.8E-05
# 110521G151606162116307.4E-081.1E-071.4E-04
# 110521G151925193019337.5E-082.7E-077.5E-05
# 110521G152256230023027.5E-081.5E-073.2E-05
# 110522G150941102811087.6E-081.3E-075.6E-04
# 110522G152004200720098.7E-081.2E-072.0E-05
# 110523G150237024802501.1E-071.9E-071.2E-04
# 110524G152211223723301.3E-072.0E-078.8E-04
# 110525G150341043004579.7E-081.9E-077.1E-04
# 110525G151237130213348.4E-081.2E-073.8E-04
# 110525G152009201420188.1E-084.1E-071.3E-04
# 110525G152056210321129.5E-081.1E-067.2E-04
# 110525G152150215822031.1E-071.4E-065.8E-04
# 110525G152225223122391.4E-073.0E-072.0E-04
# 110526G150021002500288.4E-081.2E-073.6E-05
# 110526G150101011001151.3E-074.4E-072.3E-04
# 110526G151646165417111.1E-071.9E-072.4E-04
# 110527G150950095309591.9E-074.4E-071.6E-04
# 110527G151158121512383.1E-077.7E-071.5E-03
# 110527G151441145315022.2E-072.1E-061.7E-03
# 110527G151557160116152.5E-073.9E-073.4E-04
# 110527G151638164316472.7E-075.6E-061.7E-03
# 110527G151753180418106.4E-071.1E-061.0E-03
# 110527G151933194319587.0E-071.4E-061.7E-03
# 110527G152058210521123.6E-079.3E-075.6E-04
# 110527G152232224623104.6E-070.099882.0E-03
# 110528G150027003500436.5E-071.4E-061.0E-03
# 110528G150222023202514.1E-071.6E-062.1E-03
# 110528G150304033103437.1E-078.3E-061.0E-02
# 110528G150615061906236.2E-071.7E-065.0E-04
# 110528G150651071107238.2E-072.1E-062.9E-03
# 110528G150801080608091.0E-064.4E-061.2E-03
# 110528G150843090109062.3E-067.7E-066.8E-03
# 110528G151022103011217.1E-075.3E-061.4E-02
# 110528G151242124512481.0E-061.9E-064.1E-04
# 110528G151311131513178.9E-071.4E-063.1E-04
# 110528G151337134013437.4E-071.0E-062.4E-04
# 110528G151520152515296.4E-071.2E-064.6E-04
# 110528G151539154315476.5E-071.0E-063.4E-04
# 110528G151720172317264.7E-071.9E-063.8E-04
# 110528G151842184618507.5E-072.2E-066.7E-04
# 110528G151944195320015.9E-071.2E-061.0E-03
# 110528G152109215022011.0E-061.1E-052.3E-02
# 110528G152257230023051.5E-062.4E-067.8E-04
# 110528G152341234623538.9E-071.4E-067.8E-04
# 110529G150009001400218.2E-072.1E-061.0E-03
# 110529G150133014201457.0E-074.6E-061.8E-03
# 110529G150154015902031.9E-065.9E-062.0E-03
# 110529G150526053105356.7E-071.0E-064.1E-04
# 110529G150612061706224.6E-071.8E-067.2E-04
# 110529G150713071607194.9E-079.4E-072.0E-04
# 110529G150725073007354.5E-070.099749.8E-04
# 110529G150807083308486.3E-072.4E-064.5E-03
# 110529G150857090009021.1E-061.6E-062.8E-04
# 110529G150916092409278.8E-073.7E-061.4E-03
# 110529G150944094709491.1E-063.0E-064.5E-04
# 110529G151008103311082.2E-061.4E-053.8E-02
# 110529G151136113911424.1E-067.7E-061.6E-03
# 110529G152011212021486.9E-078.7E-062.1E-02
# 110530G150247025202556.4E-070.099677.7E-04
# 110530G150546054905511.6E-063.5E-065.3E-04
# 110530G150559060506071.7E-067.0E-061.8E-03
# 110530G151048110111227.7E-072.8E-064.3E-03
# 110530G152003200720094.2E-076.7E-071.4E-04
# 110531G150434044304496.5E-071.8E-061.2E-03
# 110531G150529055306206.3E-071.7E-064.3E-03
# 110531G151708171217143.6E-076.9E-071.4E-04

# %%
# Tiene líneas "raras", seguramente por caracteres de inicio o fin de fichero
! grep 'SELDADS' flare_all.txt
# Out:
# SELDADS X-RAY Data for 2012-01-01
# SELDADS X-RAY Data for 2012-02-01
# SELDADS X-RAY Data for 2012-03-01
# SELDADS X-RAY Data for 2012-04-01
# SELDADS X-RAY Data for 2012-05-01
# SELDADS X-RAY Data for 2012-06-01
# SELDADS X-RAY Data for 2012-07-01
# SELDADS X-RAY Data for 2012-08-01
# SELDADS X-RAY Data for 2012-10-01
# SELDADS X-RAY Data for 2012-11-01
# SELDADS X-RAY Data for 2012-12-01
# SELDADS X-RAY Data for 2013-01-01
# SELDADS X-RAY Data for 2013-02-01
# SELDADS X-RAY Data for 2013-03-01
# SELDADS X-RAY Data for 2013-04-01
# SELDADS X-RAY Data for 2013-05-01
# SELDADS X-RAY Data for 2013-06-01
# SELDADS X-RAY Data for 2013-07-01
# SELDADS X-RAY Data for 2013-08-01
# SELDADS X-RAY Data for 2013-09-01
# SELDADS X-RAY Data for 2013-10-01
# SELDADS X-RAY Data for 2013-11-01
# SELDADS X-RAY Data for 2013-12-01
# SELDADS X-RAY Data for 2014-01-01
# SELDADS X-RAY Data for 2014-02-01
# SELDADS X-RAY Data for 2014-03-01
# SELDADS X-RAY Data for 2014-04-01
# SELDADS X-RAY Data for 2014-05-01
# SELDADS X-RAY Data for 2014-06-01
# SELDADS X-RAY Data for 2014-07-01
# SELDADS X-RAY Data for 2014-08-01
# SELDADS X-RAY Data for 2014-09-01
# SELDADS X-RAY Data for 2014-10-01
# SELDADS X-RAY Data for 2014-11-01
# SELDADS X-RAY Data for 2014-12-01
# SELDADS X-RAY Data for 2015-01-01
# SELDADS X-RAY Data for 2015-02-01
# SELDADS X-RAY Data for 2015-03-01
# SELDADS X-RAY Data for 2015-04-01
# SELDADS X-RAY Data for 2015-05-01
# SELDADS X-RAY Data for 2015-06-01
# SELDADS X-RAY Data for 2015-07-01
# SELDADS X-RAY Data for 2015-08-01
# SELDADS X-RAY Data for 2015-09-01
# SELDADS X-RAY Data for 2015-10-01
# SELDADS X-RAY Data for 2015-11-01
# SELDADS X-RAY Data for 2015-12-01
# SELDADS X-RAY Data for 2016-01-01
# SELDADS X-RAY Data for 2016-02-01
# SELDADS X-RAY Data for 2016-03-01
# SELDADS X-RAY Data for 2016-04-01
# SELDADS X-RAY Data for 2016-05-01
# SELDADS X-RAY Data for 2016-06-01
# SELDADS X-RAY Data for 2016-07-01
# SELDADS X-RAY Data for 2016-08-01
# SELDADS X-RAY Data for 2016-09-01
# SELDADS X-RAY Data for 2016-10-01
# SELDADS X-RAY Data for 2016-11-01
# SELDADS X-RAY Data for 2016-12-01
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT
# SELDADS NESDIS XRAYEVENT

# %%
# Las eliminamos
! sed -i '/SELDADS/d' flare_all.txt

# %%
# También hay otros caracteres raros
! grep '' flare_all.txt
# Out:
# 930101GO70459050305031.5E-097.7E-092.4E-04
# 940101GO60323032603291.3E-062.1E-066.9E-04
# 950102GO70254030503226.7E-085.5E-076.3E-04
# 960103GO81020102610327.3E-081.2E-077.9E-05
# 970120GO80827083308489.4E-094.2E-073.4E-04
# 980101GO80120013401391.9E-071.7E-068.8E-04
# 010101GO80007001300205.5E-071.3E-068.1E-04
# 050101XXX0001003100391.4E-071.7E-049.2E-02
# 100101G141202120912187.0E-081.9E-071.5E-04

# %%
# Los eliminamos
! sed -i '//d' flare_all.txt

# %%
# Y más...
! grep 'End' flare_all.txt
# Out:
# ***** End of File (31 Dec 2013)
# *****End of File: 31 Dec 14
# End of File: 31 Dec 2015
# End of File: 31 Dec 2016

# %%
# Los eliminamos también
! sed -i '/End/d' flare_all.txt

# %%
# Con la descripción del fichero (ver "xray-flares_description") ya podemos integrar nuestros datos
specs = [(0, 2), (2, 4), (4, 6), (6, 9), (9, 13), (13, 17), (17, 21), (21, 28), (28, 35), (35, 42)]
columns = ['Year', 'Month', 'Day', 'Station', 'Start_time', 'Max_time', 'End_time', 'Background_energy',
            'Peak_energy', 'Integrated_energy']

df = pd.read_fwf('flare_all.txt', header = None, names = columns, colspecs = specs)
df
# Out:
#        Year  Month   Day Station  Start_time  Max_time  End_time  \
# 0      12.0    1.0   1.0     G15       445.0     450.0     457.0
# 1      12.0    1.0   1.0     G15       724.0     734.0     744.0
# 2      12.0    1.0   1.0     G15      1322.0    1326.0    1333.0
# 3      12.0    1.0   1.0     G15      1854.0    1859.0    1906.0
# 4      12.0    1.0   1.0     G15      2328.0    2336.0    2346.0
# ...     ...    ...   ...     ...         ...       ...       ...
# 53700  11.0    5.0  30.0     G15      1048.0    1101.0    1122.0
# 53701  11.0    5.0  30.0     G15      2003.0    2007.0    2009.0
# 53702  11.0    5.0  31.0     G15       434.0     443.0     449.0
# 53703  11.0    5.0  31.0     G15       529.0     553.0     620.0
# 53704  11.0    5.0  31.0     G15      1708.0    1712.0    1714.0
#
#       Background_energy Peak_energy  Integrated_energy
# 0               4.5E-07     8.1E-07            0.00044
# 1               7.4E-07     3.2E-06            0.00280
# 2               5.2E-07     8.0E-07            0.00041
# 3               5.5E-07     8.9E-07            0.00049
# 4               6.5E-07     1.3E-06            0.00110
# ...                 ...         ...                ...
# 53700           7.7E-07     2.8E-06            0.00430
# 53701           4.2E-07     6.7E-07            0.00014
# 53702           6.5E-07     1.8E-06            0.00120
# 53703           6.3E-07     1.7E-06            0.00430
# 53704           3.6E-07     6.9E-07            0.00014
#
# [53705 rows x 10 columns]

# %%
# Un poco de información
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53705 entries, 0 to 53704
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               53697 non-null  float64
#  1   Month              53697 non-null  float64
#  2   Day                53697 non-null  float64
#  3   Station            53697 non-null  object
#  4   Start_time         53697 non-null  float64
#  5   Max_time           53697 non-null  float64
#  6   End_time           53697 non-null  float64
#  7   Background_energy  53697 non-null  object
#  8   Peak_energy        53697 non-null  object
#  9   Integrated_energy  53694 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.1+ MB

# %%
# Quitamos las columnas "Background_energy" y "Integrated_energy", nos quedaremos solo con "Peak_energy"
df.drop(['Background_energy', 'Integrated_energy'], axis = 'columns', inplace = True)

# %%
# La columna "Peak_energy" la ha tomado como tipo object, lo que quiere decir que tiene algún carácter
# raro que no hemos limpiado. Se pueden localizar al intentar pasarlas a float. Los sacamos y eliminamos:
df.drop(df[df['Peak_energy'] == '///////'].index, inplace = True)

# %%
# Ahora si, la convertimos a float
df['Peak_energy'] = df['Peak_energy'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53690 entries, 0 to 53704
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         53682 non-null  float64
#  1   Month        53682 non-null  float64
#  2   Day          53682 non-null  float64
#  3   Station      53682 non-null  object
#  4   Start_time   53682 non-null  float64
#  5   Max_time     53682 non-null  float64
#  6   End_time     53682 non-null  float64
#  7   Peak_energy  53682 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 3.7+ MB

# %%
# Veamos los NaN
df.isna().sum()
# Out:
# Year           8
# Month          8
# Day            8
# Station        8
# Start_time     8
# Max_time       8
# End_time       8
# Peak_energy    8
# dtype: int64

# %%
# Son muy pocos, eliminamos las lineas directamente
df = df.dropna()

# %%
# El año está en formato de dos dígitos, tenemos que convertirlo a formato estándar de 4, lo haremos mediante una función:
def Year_complete(value):
    result = 0
    if (value > 50) and (value <= 99):
        result = value + 1900
    elif (value >= 0) and (value <= 50):
        result = value + 2000
        
    return result

# %%
# Aplicamos la función a la columna "Year"
df['Year'] = df['Year'].apply(Year_complete)

# %%
# Transformamos los campos de fecha en una nueva columna para agrupar posteriormente
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# %%
# Las columnas separadas de fecha ya no nos interesan, asi como "Station"
df.drop(['Year', 'Month', 'Day', 'Station'], axis = 'columns', inplace = True)

# %%
# A partir de las columnas "Start_time" y "End_time" queremos sacar información sobre la duración del evento.
# Para ello crearemos una nueva columna que será "End_time" - "Start_time", duración en minutos

# %%
s = df['Start_time'].astype(int).astype(str).str.zfill(4)
df['s_t_1'] = s.str[:2] + ':' + s.str[2:] + ':00'
df['s_t_2'] = pd.to_timedelta(df['s_t_1'])

# %%
s = df['End_time'].astype(int).astype(str).str.zfill(4)
df['e_t_1'] = s.str[:2] + ':' + s.str[2:] + ':00'
df['e_t_2'] = pd.to_timedelta(df['e_t_1'])

# %%
df['Dur'] = df['e_t_2'] - df['s_t_2']

# %%
df[["hour","minute","second"]] = df['Dur'].dt.components.iloc[:, 1:4]

# %%
df['Duration'] = (df['hour'] * 60) + df['minute']

# %%
# Las columnas intermedias no nos hacen falta ya
df.drop(['Start_time', 'Max_time', 'End_time', 's_t_1', 's_t_2', 'e_t_1', 'e_t_2', 'Dur',
        'hour', 'minute', 'second'], axis = 'columns', inplace = True)

# %%
# Reordenamos
df = df[['Date', 'Duration', 'Peak_energy']]
df
# Out:
#             Date  Duration   Peak_energy
# 0     2012-01-01        12  8.100000e-07
# 1     2012-01-01        20  3.200000e-06
# 2     2012-01-01        11  8.000000e-07
# 3     2012-01-01        12  8.900000e-07
# 4     2012-01-01        18  1.300000e-06
# ...          ...       ...           ...
# 53700 2011-05-30        34  2.800000e-06
# 53701 2011-05-30         6  6.700000e-07
# 53702 2011-05-31        15  1.800000e-06
# 53703 2011-05-31        51  1.700000e-06
# 53704 2011-05-31         6  6.900000e-07
#
# [53682 rows x 3 columns]

# %%
# Vamos a agrupar por fecha, el valor que nos interesa será la media de las mediciones para cada dia
df_g = df.groupby('Date').mean().reset_index()
df_g
# Out:
#            Date    Duration   Peak_energy
# 0    1992-07-01    6.809524  3.923810e-08
# 1    1992-07-02    6.500000  4.200000e-08
# 2    1992-07-03   60.000000  2.300000e-06
# 3    1992-07-04    6.500000  2.190000e-07
# 4    1992-07-05   11.875000  7.346875e-07
# ...         ...         ...           ...
# 6244 2016-12-26   14.000000  4.375000e-07
# 6245 2016-12-27   20.333333  2.066667e-07
# 6246 2016-12-29    9.000000  1.300000e-07
# 6247 2016-12-30   11.500000  1.600000e-07
# 6248 2016-12-31  111.500000  2.100000e-07
#
# [6249 rows x 3 columns]

# %%
# Información estadística
df_g.describe()
# Out:
#           Duration   Peak_energy
# count  6249.000000  6.249000e+03
# mean     19.297651  4.960219e-05
# std      21.529795  9.181710e-04
# min       3.000000  3.300000e-09
# 25%      10.937500  3.866667e-07
# 50%      14.833333  1.133548e-06
# 75%      21.000000  2.838571e-06
# max     625.000000  3.328443e-02

# %%
# Vamos a tratar los outliers, para ello intentamos obtener un poco de información sobre la distribución de cada campo.
# En base a esta información y a los valores de media y desviación estándar tomaremos las decisiones

# %%
# Peak_energy
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['Peak_energy'], ax = ax[0])
sns.boxplot(df_g['Peak_energy'], ax = ax[1])
fig.show()

# %%
# Vamos a ver la distribución un poco más en detalle, la dividimos en tramos teniendo en cuenta el mínimo y máximo
cond1 = (df_g['Peak_energy'] >= 1e-9) & (df_g['Peak_energy'] < 1e-8) 
cond2 = (df_g['Peak_energy'] >= 1e-8) & (df_g['Peak_energy'] < 1e-7) 
cond3 = (df_g['Peak_energy'] >= 1e-7) & (df_g['Peak_energy'] < 1e-6) 
cond4 = (df_g['Peak_energy'] >= 1e-6) & (df_g['Peak_energy'] < 1e-5) 
cond5 = (df_g['Peak_energy'] >= 1e-5) & (df_g['Peak_energy'] < 1e-4) 
cond6 = (df_g['Peak_energy'] >= 1e-4) & (df_g['Peak_energy'] < 1e-3) 
cond7 = (df_g['Peak_energy'] >= 1e-3) & (df_g['Peak_energy'] < 1e-2) 
cond8 = (df_g['Peak_energy'] >= 1e-2)  

print(len(df_g[cond1]), len(df_g[cond2]), len(df_g[cond3]), len(df_g[cond4]), len(df_g[cond5]), len(df_g[cond6]),
     len(df_g[cond7]), len(df_g[cond8]))
# Out:
# 4 127 2799 2946 335 18 7 13

# %%
# Quitamos los valores más altos por arriba
df_g.drop(df_g[df_g['Peak_energy'] > 1e-4].index, inplace = True)

# %%
# Y el valor que más se pierde por abajo
df_g.drop(df_g[df_g['Peak_energy'] < 1e-8].index, inplace = True)

# %%
# Duration
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['Duration'], ax = ax[0])
sns.boxplot(df_g['Duration'], ax = ax[1])
fig.show()

# %%
# Tomamos 250 como valor "prudente" y eliminamos a partir de este
df_g.drop(df_g[df_g['Duration'] > 250].index, inplace = True)

# %%
# Guardamos
df_g.to_csv('Flares_new.csv', index = False)

# %% [markdown]
# # CMEs

# %%
# Echemos un vistazo al fichero de CMEs
! cat "Ficheros/CME/univ_all.txt" | head
# Out:
#  ========= SOHO/LASCO CME CATALOG==========      LAST UPDATED: 2020/06/26 18:01
#  Date       Time     Central  Width  Linear   2nd order speed      Accel     Mass      Kinetic    MPA   Remarks
#                         PA           Speed  initial final   20R                        Energy
#
# 1996/01/11  00:14:36    267     18    499     571    426      0    -64.3*   -------    -------    272   Only C3
# 1996/01/13  22:08:30    265     16    290     278    303    372      2.8*   -------    -------    266   Only C3
# 1996/01/15  07:01:10    262     43    525     600    454      0    -31.1    -------    -------    272   Only C3
# 1996/01/22  03:11:01    105     37    267     401    130      0   -126.3*   7.1e+13*   2.5e+28*   103   Very Poor Event; Only C3
# 1996/01/26  09:16:19     90     27    262     254    271    322      1.9*   3.0e+14    1.0e+29     90   Poor Event; Only C3
# 1996/01/31  06:52:13    274     47    158     219     99      0    -12.3*   2.5e+14*   3.2e+28*   272   Poor Event; Only 3 points
# cat: write error: Broken pipe

# %%
# Con lo que vemos y las descripciones de los campos (ver "univ_all.txt") ya podemos cargar el dataframe
columns = ['Date', 'Time', 'Central_PA', 'Width', 'L_speed', '2_I_speed', '2_F_speed', '2_20R_speed', 'Acceleration',
           'Mass', 'K_energy', 'MPA', 'Remarks']
df = pd.read_fwf('Ficheros/CME/univ_all.txt', skiprows = 4, header = None, names = columns, index_col = False,
                na_values = [0, '', '--', '---', '----', '-----', '------', '-------', '********', 'Halo'])
# Incluimos 'Halo' entre los reconocibles como NaNs porque en la columna "Central_PA" las CMEs con Width = 360º vienen
# marcadas así, con la palabra 'Halo'.
df
# Out:
#              Date      Time  Central_PA  Width  L_speed  2_I_speed  2_F_speed  \
# 0      1996/01/11  00:14:36       267.0     18    499.0      571.0      426.0
# 1      1996/01/13  22:08:30       265.0     16    290.0      278.0      303.0
# 2      1996/01/15  07:01:10       262.0     43    525.0      600.0      454.0
# 3      1996/01/22  03:11:01       105.0     37    267.0      401.0      130.0
# 4      1996/01/26  09:16:19        90.0     27    262.0      254.0      271.0
# ...           ...       ...         ...    ...      ...        ...        ...
# 30316  2020/05/29  11:24:05        84.0     52    347.0      406.0      288.0
# 30317  2020/05/29  15:12:05        83.0     46    204.0      215.0      193.0
# 30318  2020/05/29  17:36:05        76.0     34    210.0      295.0      120.0
# 30319  2020/05/30  01:25:43        80.0     39    269.0      203.0      339.0
# 30320  2020/05/30  08:48:05       259.0     23    146.0      107.0      180.0
#
#        2_20R_speed Acceleration      Mass  K_energy    MPA  \
# 0              NaN       -64.3*       NaN       NaN  272.0
# 1            372.0         2.8*       NaN       NaN  266.0
# 2              NaN        -31.1       NaN       NaN  272.0
# 3              NaN      -126.3*  7.1e+13*  2.5e+28*  103.0
# 4            322.0         1.9*   3.0e+14   1.0e+29   90.0
# ...            ...          ...       ...       ...    ...
# 30316          NaN       -21.9*       NaN       NaN   68.0
# 30317          NaN        -2.8*       NaN       NaN   74.0
# 30318          NaN       -19.3*       NaN       NaN   73.0
# 30319        331.0          2.8       NaN       NaN   86.0
# 30320        399.0         6.5*       NaN       NaN  264.0
#
#                         Remarks
# 0                       Only C3
# 1                       Only C3
# 2                       Only C3
# 3      Very Poor Event; Only C3
# 4           Poor Event; Only C3
# ...                         ...
# 30316       Poor Event; Only C2
# 30317       Poor Event; Only C2
# 30318       Poor Event; Only C2
# 30319                       NaN
# 30320           Very Poor Event
#
# [30321 rows x 13 columns]

# %%
# Un poco de información...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30321 entries, 0 to 30320
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          30321 non-null  object
#  1   Time          30321 non-null  object
#  2   Central_PA    29551 non-null  float64
#  3   Width         30321 non-null  int64
#  4   L_speed       30213 non-null  float64
#  5   2_I_speed     28997 non-null  float64
#  6   2_F_speed     29756 non-null  float64
#  7   2_20R_speed   23256 non-null  float64
#  8   Acceleration  29831 non-null  object
#  9   Mass          19738 non-null  object
#  10  K_energy      19706 non-null  object
#  11  MPA           30299 non-null  float64
#  12  Remarks       21109 non-null  object
# dtypes: float64(6), int64(1), object(6)
# memory usage: 3.0+ MB

# %%
# Los campos "Acceleration" y "K_energy" hay que limpiarlos para poder tratarlos
df['Acceleration'] = df['Acceleration'].str.rstrip('*')
df['Acceleration'] = df['Acceleration'].astype(float)
df['K_energy'] = df['K_energy'].str.rstrip('*')
df['K_energy'] = df['K_energy'].astype(float)

# %%
# Nuestra columna target será "K_energy", que se calcula a partir de la masa ("Mass") y la velocidad lineal ("L_speed")
# por tanto eliminamos dichas columnas, asi como otras que no nos interesan
df.drop(['Mass', 'L_speed'], axis = 'columns', inplace = True)
df.drop(['Time', 'Remarks'], axis = 'columns', inplace = True)

# %%
# Los NaNs en "K_energy" no podemos interpolarlos, pues es la variable objetivo. Con todo el dolor del corazón los eliminamos
df = df.dropna(axis = 0, subset = ['K_energy'])

# %%
# Veamos las otras columnas
df.isna().sum()
# Out:
# Date               0
# Central_PA       614
# Width              0
# 2_I_speed        803
# 2_F_speed        134
# 2_20R_speed     3868
# Acceleration      93
# K_energy           0
# MPA               12
# dtype: int64

# %%
# Hay bastantes, interpolaremos los valores de las columnas:
df['Central_PA'] = df['Central_PA'].interpolate()
df['2_I_speed'] = df['2_I_speed'].interpolate()
df['2_F_speed'] = df['2_F_speed'].interpolate()
df['2_20R_speed'] = df['2_20R_speed'].interpolate(limit_direction = 'both')
df['Acceleration'] = df['Acceleration'].interpolate()
df['MPA'] = df['MPA'].interpolate()

# %%
# Veamos entonces como queda todo
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19706 entries, 3 to 30123
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          19706 non-null  object
#  1   Central_PA    19706 non-null  float64
#  2   Width         19706 non-null  int64
#  3   2_I_speed     19706 non-null  float64
#  4   2_F_speed     19706 non-null  float64
#  5   2_20R_speed   19706 non-null  float64
#  6   Acceleration  19706 non-null  float64
#  7   K_energy      19706 non-null  float64
#  8   MPA           19706 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
# Pasamos la fecha al formato que nos interesa
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Agrupamos por fecha, el valor que nos interesa de cada campo es la media:
df_g = df.groupby('Date').mean().reset_index()
df_g
# Out:
#            Date  Central_PA  Width  2_I_speed  2_F_speed  2_20R_speed  \
# 0    1996-01-22       105.0   37.0      401.0      130.0   322.000000
# 1    1996-01-26        90.0   27.0      254.0      271.0   322.000000
# 2    1996-01-31       274.0   47.0      219.0       99.0   315.500000
# 3    1996-02-03        83.0   52.0      294.0      317.0   309.000000
# 4    1996-02-08       263.0   70.0      247.0      126.0   272.500000
# ...         ...         ...    ...        ...        ...          ...
# 6548 2019-12-24       282.0   57.0      157.0      288.0   615.000000
# 6549 2019-12-25       274.0   49.0      337.0      245.0  1088.666667
# 6550 2019-12-26        99.0   58.0      196.0      104.0  1562.333333
# 6551 2019-12-27       293.0   33.5      275.0      592.0  1086.000000
# 6552 2019-12-30       266.5   61.0       20.5      132.0   222.500000
#
#       Acceleration      K_energy    MPA
# 0          -126.30  2.500000e+28  103.0
# 1             1.90  1.000000e+29   90.0
# 2           -12.30  3.200000e+28  272.0
# 3             0.90  8.900000e+29   80.0
# 4            -6.00  2.700000e+28  249.0
# ...            ...           ...    ...
# 6548         14.60  1.500000e+28  289.0
# 6549        -14.30  1.300000e+28  268.0
# 6550        -11.10  9.200000e+27  109.0
# 6551         81.05  3.550000e+28  292.5
# 6552          2.10  2.795000e+28  260.0
#
# [6553 rows x 9 columns]

# %%
# Comprobamos la estadística
df_g.describe()
# Out:
#         Central_PA        Width    2_I_speed    2_F_speed  2_20R_speed  \
# count  6553.000000  6553.000000  6553.000000  6553.000000  6553.000000
# mean    180.108358    69.490918   358.738062   394.005208   529.656222
# std      71.920116    47.728418   231.478827   203.495362   258.452161
# min       1.000000    11.000000     2.000000     9.000000    21.000000
# 25%     121.000000    40.000000   209.600000   265.500000   365.000000
# 50%     181.166667    57.000000   313.000000   362.142857   487.000000
# 75%     239.000000    82.000000   452.875000   478.600000   635.166667
# max     359.000000   360.000000  3703.000000  2558.000000  3294.000000
#
#        Acceleration      K_energy          MPA
# count   6553.000000  6.553000e+03  6553.000000
# mean       2.241041  5.627735e+30   180.294766
# std       20.663508  6.421144e+31    72.384148
# min     -232.000000  5.500000e+24     1.000000
# 25%       -3.800000  6.700000e+28   120.600000
# 50%        1.850000  3.855000e+29   181.250000
# 75%        7.160000  1.968700e+30   239.333333
# max      446.100000  4.200000e+33   359.000000

# %%
# Vamos con los outliers, para decidir cuales quitar usaremos gráficas de distribución así como los valores de 
# media y desviación estándar

# %%
# 2_I_speed
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['2_I_speed'], ax = ax[0])
sns.boxplot(df_g['2_I_speed'], ax = ax[1])
fig.show()

# %%
# Teniendo en cuenta lo que hemos dicho
df_g.drop(df_g[df_g['2_I_speed'] >= 1500].index, inplace =True)

# %%
# 2_F_speed
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['2_F_speed'], ax = ax[0])
sns.boxplot(df_g['2_F_speed'], ax = ax[1])
fig.show()

# %%
df_g.drop(df_g[df_g['2_F_speed'] >= 1250].index, inplace =True)

# %%
# 2_20R_speed
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['2_20R_speed'], ax = ax[0])
sns.boxplot(df_g['2_20R_speed'], ax = ax[1])
fig.show()

# %%
df_g.drop(df_g[df_g['2_20R_speed'] >= 2000].index, inplace =True)

# %%
# Acceleration
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['Acceleration'], ax = ax[0])
sns.boxplot(df_g['Acceleration'], ax = ax[1])
fig.show()

# %%
# La columna "Acceleration" es difícil por su distribución y porque se nos dice que son valores poco fiables...
df_g.drop(df_g[df_g['Acceleration'] > 150].index, inplace =True)
df_g.drop(df_g[df_g['Acceleration'] < -150].index, inplace =True)

# %%
# K_energy
sns.set(rc = {'figure.figsize':(17, 5)})
fig, ax = plt.subplots(1, 2)
sns.distplot(df_g['K_energy'], ax = ax[0])
sns.boxplot(df_g['K_energy'], ax = ax[1])
fig.show()

# %%
# Vamos a ver la distribución más en detalle, tomando intervalos lógicos entre el mínimo y el máximo
cond1 = (df_g['K_energy'] > 1e+24) & (df_g['K_energy'] < 1e+25) 
cond2 = (df_g['K_energy'] >= 1e+25) & (df_g['K_energy'] < 1e+26) 
cond3 = (df_g['K_energy'] >= 1e+26) & (df_g['K_energy'] < 1e+27)
cond4 = (df_g['K_energy'] >= 1e+27) & (df_g['K_energy'] < 1e+28) 
cond5 = (df_g['K_energy'] >= 1e+28) & (df_g['K_energy'] < 1e+29) 
cond6 = (df_g['K_energy'] >= 1e+29) & (df_g['K_energy'] < 1e+30)
cond7 = (df_g['K_energy'] >= 1e+30) & (df_g['K_energy'] < 1e+31) 
cond8 = (df_g['K_energy'] >= 1e+31) & (df_g['K_energy'] < 1e+32) 
cond9 = (df_g['K_energy'] >= 1e+32) 

print(len(df_g[cond1]), len(df_g[cond2]), len(df_g[cond3]), len(df_g[cond4]), len(df_g[cond5]), len(df_g[cond6]), 
len(df_g[cond7]), len(df_g[cond8]), len(df_g[cond9]))
# Out:
# 1 9 79 467 1423 2228 1818 450 20

# %%
# Eliminaremos los correspondientes a los tramos 1, 2 y 9
df_g.drop(df_g[cond1].index, inplace =True)
df_g.drop(df_g[cond2].index, inplace =True)
df_g.drop(df_g[cond9].index, inplace =True)

# %%
# En realidad lo que nos interesa no es el valor exacto de K_energy, sino el "rango". Para facilitar las cosas vamos a 
# discretizar la variable en una serie de tramos

# %%
# Definimos una función para clasificar los valores, asignaremos números del 1 al 6 según la intensidad de K_energy
def Classifier(value):
    result = 0
    if (value >= 1e+26) and (value < 1e+27):
        result = 1
    elif (value >= 1e+27) and (value < 1e+28):
        result = 2
    elif (value >= 1e+28) and (value < 1e+29):
        result = 3
    elif (value >= 1e+29) and (value < 1e+30):
        result = 4
    elif (value >= 1e+30) and (value < 1e+31):
        result = 5
    elif (value >= 1e+31):
        result = 6
    
    return result

# %%
# Creamos una nueva columna con dicha clasificación
df_g['Class'] = df_g['K_energy'].apply(Classifier)

# %%
# Ya no necesitamos K_energy
df_g.drop(['K_energy'], axis = 'columns', inplace = True)

# %%
df_g
# Out:
#            Date  Central_PA  Width  2_I_speed  2_F_speed  2_20R_speed  \
# 0    1996-01-22       105.0   37.0      401.0      130.0   322.000000
# 1    1996-01-26        90.0   27.0      254.0      271.0   322.000000
# 2    1996-01-31       274.0   47.0      219.0       99.0   315.500000
# 3    1996-02-03        83.0   52.0      294.0      317.0   309.000000
# 4    1996-02-08       263.0   70.0      247.0      126.0   272.500000
# ...         ...         ...    ...        ...        ...          ...
# 6548 2019-12-24       282.0   57.0      157.0      288.0   615.000000
# 6549 2019-12-25       274.0   49.0      337.0      245.0  1088.666667
# 6550 2019-12-26        99.0   58.0      196.0      104.0  1562.333333
# 6551 2019-12-27       293.0   33.5      275.0      592.0  1086.000000
# 6552 2019-12-30       266.5   61.0       20.5      132.0   222.500000
#
#       Acceleration    MPA  Class
# 0          -126.30  103.0      3
# 1             1.90   90.0      4
# 2           -12.30  272.0      3
# 3             0.90   80.0      4
# 4            -6.00  249.0      3
# ...            ...    ...    ...
# 6548         14.60  289.0      3
# 6549        -14.30  268.0      3
# 6550        -11.10  109.0      2
# 6551         81.05  292.5      3
# 6552          2.10  260.0      3
#
# [6465 rows x 9 columns]

# %%
# Guardamos
df_g.to_csv('CMEs_new.csv', index = False)
